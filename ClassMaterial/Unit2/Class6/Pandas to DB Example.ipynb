# %% [markdown]
# ### Connecting Pandas to a Database
#
# This notebook will walk us through how to use pandas to interact with a database, and then query an API and add new values to it.
#
# Running this code continuously will allow us to programmatically collect a unique data source.

# %%
import pandas as pd
import numpy as np
# you will need to import this -- pip install SQLAlchemy
from sqlalchemy import create_engine, types
# you will need to import this -- pip install mysql-connector-python
import mysql.connector
import requests
# you will need to install this  -- pip install requests-oauthlib
from requests_oauthlib import OAuth1

# %% [markdown]
# ### Step 1:  Fetching the Data From the Database

# %%
# we'll create a dictionary to store all of our database information
df_dict = {
    'connector': 'mysql+mysqlconnector',
    'username' : 'dat1019',
    'password' : 'dat1019password',
    'server'   : 'dat-10-19.cfvn8ddij95j.us-east-1.rds.amazonaws.com',
    'port'     : '3306',
    'database' : 'dat1019'
}

# %%
# this string contains all the information
connection_string = f"{df_dict['connector']}://{df_dict['username']}:{df_dict['password']}@{df_dict['server']}:{df_dict['port']}/{df_dict['database']}"

# %%
connection_string
# Out:
# 'mysql+mysqlconnector://dat1019:dat1019password@dat-10-19.cfvn8ddij95j.us-east-1.rds.amazonaws.com:3306/dat1019'

# %%
# this is what we need to connect to our database
engine = create_engine(connection_string)

# %%
# we'll now connect to the database and pull in the info
with engine.connect() as connection:
    tweets = pd.read_sql_query("SELECT * FROM tweets", con=connection)

# %%
# let's look at our results
tweets.head()
# Out:
#               name      screen_name  \
# 0  Donald J. Trump  realDonaldTrump
# 1  Donald J. Trump  realDonaldTrump
# 2  Donald J. Trump  realDonaldTrump
# 3  Donald J. Trump  realDonaldTrump
# 4  Donald J. Trump  realDonaldTrump
#
#                                                 text  retweets  favorites  \
# 0  RT @realDonaldTrump: VOTE! VOTE! VOTE!\nhttps:...    117124          0
# 1                            https://t.co/zX4bqgtWqH     10186      47177
# 2                            https://t.co/SMaOF79kPV     10806      44040
# 3  RT @BarstoolNewsN: The Amish are not playing a...     17887          0
# 4  A parade for me in Nigeria, a great honor! htt...     39398     199959
#
#                     id
# 0  1323692146147340299
# 1  1323692020880297986
# 2  1323691984989622272
# 3  1323684790894297089
# 4  1323680963310866435

# %%
# we will turn this column into a string -- useful for later processing
tweets['id'] = tweets.id.astype(str)

# %% [markdown]
# ### Step 2:  Getting API Data

# %%
# authorization information for the Twitter API
tokens = OAuth1('NOZHm1aLT1AVmchGbCmiZOAga', 'nPyaYCt8L7ymqGZtU8EqC0a2ypI9aSJgVNIhtoZ0wGsaf3BJw9',
                '1079981876864008192-AlhO4yOa06oW2sXZpLpWPwnOxEERYS', 'o3E0AsKJfDoTBk77UQYExzOG7E46jPYvpWNGAKsD6lUBY')

# %%
# the api endpoint we'll ping to get our API results
base_url = 'https://api.twitter.com/1.1/statuses/user_timeline.json?screen_name=realDonaldTrump&count=200'

# %%
# this is our list of dictionaries that contains Donald Trump's tweets
tweet_results = requests.get(base_url, auth=tokens).json()

# %%
# here's our resulting dictionary
tweet_results
# Out:
# [{'created_at': 'Tue Nov 03 19:51:40 +0000 2020',
#   'id': 1323714481353068546,
#   'id_str': '1323714481353068546',
#   'text': 'RT @realDonaldTrump: VOTE! VOTE! VOTE!\nhttps://t.co/85ySh1KYkh',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'realDonaldTrump',
#      'name': 'Donald J. Trump',
#      'id': 25073877,
#      'id_str': '25073877',
#      'indices': [3, 19]}],
#    'urls': [],
#    'media': [{'id': 1323298431088107520,
#      'id_str': '1323298431088107520',
#      'indices': [39, 62],
#      'media_url': 'http://pbs.twimg.com/amplify_video_thumb/1323298431088107520/img/XSsqukn6q0bMx8Dj.jpg',
#      'media_url_https': 'https://pbs.twimg.com/amplify_video_thumb/1323298431088107520/img/XSsqukn6q0bMx8Dj.jpg',
#      'url': 'https://t.co/85ySh1KYkh',
#      'display_url': 'pic.twitter.com/85ySh1KYkh',
#      'expanded_url': 'https://twitter.com/som3thingwicked/status/1323300764853350401/video/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#       'large': {'w': 1280, 'h': 720, 'resize': 'fit'}},
#      'source_status_id': 1323300764853350401,
#      'source_status_id_str': '1323300764853350401',
#      'source_user_id': 41144411,
#      'source_user_id_str': '41144411'}]},
#   'extended_entities': {'media': [{'id': 1323298431088107520,
#      'id_str': '1323298431088107520',
#      'indices': [39, 62],
#      'media_url': 'http://pbs.twimg.com/amplify_video_thumb/1323298431088107520/img/XSsqukn6q0bMx8Dj.jpg',
#      'media_url_https': 'https://pbs.twimg.com/amplify_video_thumb/1323298431088107520/img/XSsqukn6q0bMx8Dj.jpg',
#      'url': 'https://t.co/85ySh1KYkh',
#      'display_url': 'pic.twitter.com/85ySh1KYkh',
#      'expanded_url': 'https://twitter.com/som3thingwicked/status/1323300764853350401/video/1',
#      'type': 'video',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#       'large': {'w': 1280, 'h': 720, 'resize': 'fit'}},
#      'source_status_id': 1323300764853350401,
#      'source_status_id_str': '1323300764853350401',
#      'source_user_id': 41144411,
#      'source_user_id_str': '41144411',
#      'video_info': {'aspect_ratio': [16, 9],
#       'duration_millis': 132366,
#       'variants': [{'bitrate': 832000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/amplify_video/1323298431088107520/vid/640x360/-xn4g30YvnwdA9IC.mp4?tag=13'},
#        {'bitrate': 288000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/amplify_video/1323298431088107520/vid/480x270/Fbn1Q_eTWKPMvrIw.mp4?tag=13'},
#        {'bitrate': 2176000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/amplify_video/1323298431088107520/vid/1280x720/ko9kWFOoAhotnGb5.mp4?tag=13'},
#        {'content_type': 'application/x-mpegURL',
#         'url': 'https://video.twimg.com/amplify_video/1323298431088107520/pl/rc4vG5ucYS8s05M9.m3u8?tag=13'}]},
#      'additional_media_info': {'title': 'POTUS knows how to close a show!',
#       'description': 'Trump dancing to YMCA',
#       'embeddable': True,
#       'monetizable': False,
#       'source_user': {'id': 41144411,
#        'id_str': '41144411',
#        'name': '4 MORE YEARS - #JoinTheMovement #VoteToday',
#        'screen_name': 'som3thingwicked',
#        'location': 'Texas',
#        'description': 'Digital graffiti 🃏',
#        'url': 'https://t.co/3YXwZ2lbMu',
#        'entities': {'url': {'urls': [{'url': 'https://t.co/3YXwZ2lbMu',
#            'expanded_url': 'https://www.youtube.com/c/SOMETHiNGWiCK%C3%8BD',
#            'display_url': 'youtube.com/c/SOMETHiNGWiC…',
#            'indices': [0, 23]}]},
#         'description': {'urls': []}},
#        'protected': False,
#        'followers_count': 54392,
#        'friends_count': 98,
#        'listed_count': 242,
#        'created_at': 'Tue May 19 16:03:13 +0000 2009',
#        'favourites_count': 33884,
#        'utc_offset': None,
#        'time_zone': None,
#        'geo_enabled': False,
#        'verified': False,
#        'statuses_count': 14072,
#        'lang': None,
#        'contributors_enabled': False,
#        'is_translator': False,
#        'is_translation_enabled': False,
#        'profile_background_color': '000000',
#        'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#        'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#        'profile_background_tile': False,
#        'profile_image_url': 'http://pbs.twimg.com/profile_images/1209682805011230725/IN6dZvfH_normal.jpg',
#        'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1209682805011230725/IN6dZvfH_normal.jpg',
#        'profile_banner_url': 'https://pbs.twimg.com/profile_banners/41144411/1604384914',
#        'profile_link_color': '3B94D9',
#        'profile_sidebar_border_color': '000000',
#        'profile_sidebar_fill_color': '000000',
#        'profile_text_color': '000000',
#        'profile_use_background_image': False,
#        'has_extended_profile': False,
#        'default_profile': False,
#        'default_profile_image': False,
#        'following': False,
#        'follow_request_sent': False,
#        'notifications': False,
#        'translator_type': 'none'}}}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 25073877,
#    'id_str': '25073877',
#    'name': 'Donald J. Trump',
#    'screen_name': 'realDonaldTrump',
#    'location': 'Washington, DC',
#    'description': '45th President of the United States of America🇺🇸',
#    'url': 'https://t.co/8f9VFxztEJ',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/8f9VFxztEJ',
#        'expanded_url': 'http://Vote.DonaldJTrump.com',
#        'display_url': 'Vote.DonaldJTrump.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 87453818,
#    'friends_count': 50,
#    'listed_count': 122624,
#    'created_at': 'Wed Mar 18 13:46:38 +0000 2009',
#    'favourites_count': 6,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 58111,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': '6D5C18',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25073877/1604214583',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': 'BDDCAD',
#    'profile_sidebar_fill_color': 'C5CEC0',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Tue Nov 03 07:57:08 +0000 2020',
#    'id': 1323534663453913093,
#    'id_str': '1323534663453913093',
#    'text': 'VOTE! VOTE! VOTE!\nhttps://t.co/85ySh1KYkh',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [],
#     'media': [{'id': 1323298431088107520,
#       'id_str': '1323298431088107520',
#       'indices': [18, 41],
#       'media_url': 'http://pbs.twimg.com/amplify_video_thumb/1323298431088107520/img/XSsqukn6q0bMx8Dj.jpg',
#       'media_url_https': 'https://pbs.twimg.com/amplify_video_thumb/1323298431088107520/img/XSsqukn6q0bMx8Dj.jpg',
#       'url': 'https://t.co/85ySh1KYkh',
#       'display_url': 'pic.twitter.com/85ySh1KYkh',
#       'expanded_url': 'https://twitter.com/som3thingwicked/status/1323300764853350401/video/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#        'large': {'w': 1280, 'h': 720, 'resize': 'fit'}},
#       'source_status_id': 1323300764853350401,
#       'source_status_id_str': '1323300764853350401',
#       'source_user_id': 41144411,
#       'source_user_id_str': '41144411'}]},
#    'extended_entities': {'media': [{'id': 1323298431088107520,
#       'id_str': '1323298431088107520',
#       'indices': [18, 41],
#       'media_url': 'http://pbs.twimg.com/amplify_video_thumb/1323298431088107520/img/XSsqukn6q0bMx8Dj.jpg',
#       'media_url_https': 'https://pbs.twimg.com/amplify_video_thumb/1323298431088107520/img/XSsqukn6q0bMx8Dj.jpg',
#       'url': 'https://t.co/85ySh1KYkh',
#       'display_url': 'pic.twitter.com/85ySh1KYkh',
#       'expanded_url': 'https://twitter.com/som3thingwicked/status/1323300764853350401/video/1',
#       'type': 'video',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#        'large': {'w': 1280, 'h': 720, 'resize': 'fit'}},
#       'source_status_id': 1323300764853350401,
#       'source_status_id_str': '1323300764853350401',
#       'source_user_id': 41144411,
#       'source_user_id_str': '41144411',
#       'video_info': {'aspect_ratio': [16, 9],
#        'duration_millis': 132366,
#        'variants': [{'bitrate': 832000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/amplify_video/1323298431088107520/vid/640x360/-xn4g30YvnwdA9IC.mp4?tag=13'},
#         {'bitrate': 288000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/amplify_video/1323298431088107520/vid/480x270/Fbn1Q_eTWKPMvrIw.mp4?tag=13'},
#         {'bitrate': 2176000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/amplify_video/1323298431088107520/vid/1280x720/ko9kWFOoAhotnGb5.mp4?tag=13'},
#         {'content_type': 'application/x-mpegURL',
#          'url': 'https://video.twimg.com/amplify_video/1323298431088107520/pl/rc4vG5ucYS8s05M9.m3u8?tag=13'}]},
#       'additional_media_info': {'title': 'POTUS knows how to close a show!',
#        'description': 'Trump dancing to YMCA',
#        'embeddable': True,
#        'monetizable': False,
#        'source_user': {'id': 41144411,
#         'id_str': '41144411',
#         'name': '4 MORE YEARS - #JoinTheMovement #VoteToday',
#         'screen_name': 'som3thingwicked',
#         'location': 'Texas',
#         'description': 'Digital graffiti 🃏',
#         'url': 'https://t.co/3YXwZ2lbMu',
#         'entities': {'url': {'urls': [{'url': 'https://t.co/3YXwZ2lbMu',
#             'expanded_url': 'https://www.youtube.com/c/SOMETHiNGWiCK%C3%8BD',
#             'display_url': 'youtube.com/c/SOMETHiNGWiC…',
#             'indices': [0, 23]}]},
#          'description': {'urls': []}},
#         'protected': False,
#         'followers_count': 54392,
#         'friends_count': 98,
#         'listed_count': 242,
#         'created_at': 'Tue May 19 16:03:13 +0000 2009',
#         'favourites_count': 33884,
#         'utc_offset': None,
#         'time_zone': None,
#         'geo_enabled': False,
#         'verified': False,
#         'statuses_count': 14072,
#         'lang': None,
#         'contributors_enabled': False,
#         'is_translator': False,
#         'is_translation_enabled': False,
#         'profile_background_color': '000000',
#         'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#         'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#         'profile_background_tile': False,
#         'profile_image_url': 'http://pbs.twimg.com/profile_images/1209682805011230725/IN6dZvfH_normal.jpg',
#         'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1209682805011230725/IN6dZvfH_normal.jpg',
#         'profile_banner_url': 'https://pbs.twimg.com/profile_banners/41144411/1604384914',
#         'profile_link_color': '3B94D9',
#         'profile_sidebar_border_color': '000000',
#         'profile_sidebar_fill_color': '000000',
#         'profile_text_color': '000000',
#         'profile_use_background_image': False,
#         'has_extended_profile': False,
#         'default_profile': False,
#         'default_profile_image': False,
#         'following': False,
#         'follow_request_sent': False,
#         'notifications': False,
#         'translator_type': 'none'}}}]},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 25073877,
#     'id_str': '25073877',
#     'name': 'Donald J. Trump',
#     'screen_name': 'realDonaldTrump',
#     'location': 'Washington, DC',
#     'description': '45th President of the United States of America🇺🇸',
#     'url': 'https://t.co/8f9VFxztEJ',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/8f9VFxztEJ',
#         'expanded_url': 'http://Vote.DonaldJTrump.com',
#         'display_url': 'Vote.DonaldJTrump.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 87453818,
#     'friends_count': 50,
#     'listed_count': 122624,
#     'created_at': 'Wed Mar 18 13:46:38 +0000 2009',
#     'favourites_count': 6,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': True,
#     'statuses_count': 58111,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': True,
#     'profile_background_color': '6D5C18',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25073877/1604214583',
#     'profile_link_color': '1B95E0',
#     'profile_sidebar_border_color': 'BDDCAD',
#     'profile_sidebar_fill_color': 'C5CEC0',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'regular'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 121165,
#    'favorite_count': 575854,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'fr'},
#   'is_quote_status': False,
#   'retweet_count': 121165,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'fr'},
#  {'created_at': 'Tue Nov 03 19:51:19 +0000 2020',
#   'id': 1323714393184653323,
#   'id_str': '1323714393184653323',
#   'text': 'RT @realDonaldTrump: https://t.co/gsFSghkmdM https://t.co/ao85KjMeBW',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'realDonaldTrump',
#      'name': 'Donald J. Trump',
#      'id': 25073877,
#      'id_str': '25073877',
#      'indices': [3, 19]}],
#    'urls': [{'url': 'https://t.co/gsFSghkmdM',
#      'expanded_url': 'http://Vote.DonaldJTrump.com',
#      'display_url': 'Vote.DonaldJTrump.com',
#      'indices': [21, 44]}],
#    'media': [{'id': 1321087638330363906,
#      'id_str': '1321087638330363906',
#      'indices': [45, 68],
#      'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1321087638330363906/pu/img/KZNBV4wAQJyN6hEW.jpg',
#      'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1321087638330363906/pu/img/KZNBV4wAQJyN6hEW.jpg',
#      'url': 'https://t.co/ao85KjMeBW',
#      'display_url': 'pic.twitter.com/ao85KjMeBW',
#      'expanded_url': 'https://twitter.com/realDonaldTrump/status/1321087723281801216/video/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#       'large': {'w': 1280, 'h': 720, 'resize': 'fit'}},
#      'source_status_id': 1321087723281801216,
#      'source_status_id_str': '1321087723281801216',
#      'source_user_id': 25073877,
#      'source_user_id_str': '25073877'}]},
#   'extended_entities': {'media': [{'id': 1321087638330363906,
#      'id_str': '1321087638330363906',
#      'indices': [45, 68],
#      'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1321087638330363906/pu/img/KZNBV4wAQJyN6hEW.jpg',
#      'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1321087638330363906/pu/img/KZNBV4wAQJyN6hEW.jpg',
#      'url': 'https://t.co/ao85KjMeBW',
#      'display_url': 'pic.twitter.com/ao85KjMeBW',
#      'expanded_url': 'https://twitter.com/realDonaldTrump/status/1321087723281801216/video/1',
#      'type': 'video',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#       'large': {'w': 1280, 'h': 720, 'resize': 'fit'}},
#      'source_status_id': 1321087723281801216,
#      'source_status_id_str': '1321087723281801216',
#      'source_user_id': 25073877,
#      'source_user_id_str': '25073877',
#      'video_info': {'aspect_ratio': [16, 9],
#       'duration_millis': 51307,
#       'variants': [{'bitrate': 2176000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/1321087638330363906/pu/vid/1280x720/bBa54IP-Rid7rS4t.mp4?tag=10'},
#        {'bitrate': 832000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/1321087638330363906/pu/vid/640x360/ZF4WVEf8rToBW3kQ.mp4?tag=10'},
#        {'bitrate': 256000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/1321087638330363906/pu/vid/480x270/FlPpnqs-n7y6sVNj.mp4?tag=10'},
#        {'content_type': 'application/x-mpegURL',
#         'url': 'https://video.twimg.com/ext_tw_video/1321087638330363906/pu/pl/2gPlM1rNLitanEyT.m3u8?tag=10'}]},
#      'additional_media_info': {'monetizable': False,
#       'source_user': {'id': 25073877,
#        'id_str': '25073877',
#        'name': 'Donald J. Trump',
#        'screen_name': 'realDonaldTrump',
#        'location': 'Washington, DC',
#        'description': '45th President of the United States of America🇺🇸',
#        'url': 'https://t.co/8f9VFxztEJ',
#        'entities': {'url': {'urls': [{'url': 'https://t.co/8f9VFxztEJ',
#            'expanded_url': 'http://Vote.DonaldJTrump.com',
#            'display_url': 'Vote.DonaldJTrump.com',
#            'indices': [0, 23]}]},
#         'description': {'urls': []}},
#        'protected': False,
#        'followers_count': 87453818,
#        'friends_count': 50,
#        'listed_count': 122624,
#        'created_at': 'Wed Mar 18 13:46:38 +0000 2009',
#        'favourites_count': 6,
#        'utc_offset': None,
#        'time_zone': None,
#        'geo_enabled': True,
#        'verified': True,
#        'statuses_count': 58111,
#        'lang': None,
#        'contributors_enabled': False,
#        'is_translator': False,
#        'is_translation_enabled': True,
#        'profile_background_color': '6D5C18',
#        'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#        'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#        'profile_background_tile': True,
#        'profile_image_url': 'http://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#        'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#        'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25073877/1604214583',
#        'profile_link_color': '1B95E0',
#        'profile_sidebar_border_color': 'BDDCAD',
#        'profile_sidebar_fill_color': 'C5CEC0',
#        'profile_text_color': '333333',
#        'profile_use_background_image': True,
#        'has_extended_profile': False,
#        'default_profile': False,
#        'default_profile_image': False,
#        'following': False,
#        'follow_request_sent': False,
#        'notifications': False,
#        'translator_type': 'regular'}}}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 25073877,
#    'id_str': '25073877',
#    'name': 'Donald J. Trump',
#    'screen_name': 'realDonaldTrump',
#    'location': 'Washington, DC',
#    'description': '45th President of the United States of America🇺🇸',
#    'url': 'https://t.co/8f9VFxztEJ',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/8f9VFxztEJ',
#        'expanded_url': 'http://Vote.DonaldJTrump.com',
#        'display_url': 'Vote.DonaldJTrump.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 87453818,
#    'friends_count': 50,
#    'listed_count': 122624,
#    'created_at': 'Wed Mar 18 13:46:38 +0000 2009',
#    'favourites_count': 6,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 58111,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': '6D5C18',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25073877/1604214583',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': 'BDDCAD',
#    'profile_sidebar_fill_color': 'C5CEC0',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Tue Oct 27 13:53:52 +0000 2020',
#    'id': 1321087723281801216,
#    'id_str': '1321087723281801216',
#    'text': 'https://t.co/gsFSghkmdM https://t.co/ao85KjMeBW',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/gsFSghkmdM',
#       'expanded_url': 'http://Vote.DonaldJTrump.com',
#       'display_url': 'Vote.DonaldJTrump.com',
#       'indices': [0, 23]}],
#     'media': [{'id': 1321087638330363906,
#       'id_str': '1321087638330363906',
#       'indices': [24, 47],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1321087638330363906/pu/img/KZNBV4wAQJyN6hEW.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1321087638330363906/pu/img/KZNBV4wAQJyN6hEW.jpg',
#       'url': 'https://t.co/ao85KjMeBW',
#       'display_url': 'pic.twitter.com/ao85KjMeBW',
#       'expanded_url': 'https://twitter.com/realDonaldTrump/status/1321087723281801216/video/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#        'large': {'w': 1280, 'h': 720, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1321087638330363906,
#       'id_str': '1321087638330363906',
#       'indices': [24, 47],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1321087638330363906/pu/img/KZNBV4wAQJyN6hEW.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1321087638330363906/pu/img/KZNBV4wAQJyN6hEW.jpg',
#       'url': 'https://t.co/ao85KjMeBW',
#       'display_url': 'pic.twitter.com/ao85KjMeBW',
#       'expanded_url': 'https://twitter.com/realDonaldTrump/status/1321087723281801216/video/1',
#       'type': 'video',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#        'large': {'w': 1280, 'h': 720, 'resize': 'fit'}},
#       'video_info': {'aspect_ratio': [16, 9],
#        'duration_millis': 51307,
#        'variants': [{'bitrate': 2176000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1321087638330363906/pu/vid/1280x720/bBa54IP-Rid7rS4t.mp4?tag=10'},
#         {'bitrate': 832000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1321087638330363906/pu/vid/640x360/ZF4WVEf8rToBW3kQ.mp4?tag=10'},
#         {'bitrate': 256000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1321087638330363906/pu/vid/480x270/FlPpnqs-n7y6sVNj.mp4?tag=10'},
#         {'content_type': 'application/x-mpegURL',
#          'url': 'https://video.twimg.com/ext_tw_video/1321087638330363906/pu/pl/2gPlM1rNLitanEyT.m3u8?tag=10'}]},
#       'additional_media_info': {'monetizable': False}}]},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 25073877,
#     'id_str': '25073877',
#     'name': 'Donald J. Trump',
#     'screen_name': 'realDonaldTrump',
#     'location': 'Washington, DC',
#     'description': '45th President of the United States of America🇺🇸',
#     'url': 'https://t.co/8f9VFxztEJ',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/8f9VFxztEJ',
#         'expanded_url': 'http://Vote.DonaldJTrump.com',
#         'display_url': 'Vote.DonaldJTrump.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 87453818,
#     'friends_count': 50,
#     'listed_count': 122624,
#     'created_at': 'Wed Mar 18 13:46:38 +0000 2009',
#     'favourites_count': 6,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': True,
#     'statuses_count': 58111,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': True,
#     'profile_background_color': '6D5C18',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25073877/1604214583',
#     'profile_link_color': '1B95E0',
#     'profile_sidebar_border_color': 'BDDCAD',
#     'profile_sidebar_fill_color': 'C5CEC0',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'regular'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 14850,
#    'favorite_count': 60555,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'und'},
#   'is_quote_status': False,
#   'retweet_count': 14850,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'und'},
#  {'created_at': 'Tue Nov 03 19:51:04 +0000 2020',
#   'id': 1323714331922583556,
#   'id_str': '1323714331922583556',
#   'text': 'RT @realDonaldTrump: https://t.co/gsFSgh2KPc https://t.co/gs5RMGGhDR',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'realDonaldTrump',
#      'name': 'Donald J. Trump',
#      'id': 25073877,
#      'id_str': '25073877',
#      'indices': [3, 19]}],
#    'urls': [{'url': 'https://t.co/gsFSgh2KPc',
#      'expanded_url': 'http://Vote.DonaldJTrump.com',
#      'display_url': 'Vote.DonaldJTrump.com',
#      'indices': [21, 44]}],
#    'media': [{'id': 1321198287836172288,
#      'id_str': '1321198287836172288',
#      'indices': [45, 68],
#      'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1321198287836172288/pu/img/GXvTxKjjCbraxJmT.jpg',
#      'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1321198287836172288/pu/img/GXvTxKjjCbraxJmT.jpg',
#      'url': 'https://t.co/gs5RMGGhDR',
#      'display_url': 'pic.twitter.com/gs5RMGGhDR',
#      'expanded_url': 'https://twitter.com/realDonaldTrump/status/1321199597952192513/video/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#       'large': {'w': 1280, 'h': 720, 'resize': 'fit'}},
#      'source_status_id': 1321199597952192513,
#      'source_status_id_str': '1321199597952192513',
#      'source_user_id': 25073877,
#      'source_user_id_str': '25073877'}]},
#   'extended_entities': {'media': [{'id': 1321198287836172288,
#      'id_str': '1321198287836172288',
#      'indices': [45, 68],
#      'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1321198287836172288/pu/img/GXvTxKjjCbraxJmT.jpg',
#      'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1321198287836172288/pu/img/GXvTxKjjCbraxJmT.jpg',
#      'url': 'https://t.co/gs5RMGGhDR',
#      'display_url': 'pic.twitter.com/gs5RMGGhDR',
#      'expanded_url': 'https://twitter.com/realDonaldTrump/status/1321199597952192513/video/1',
#      'type': 'video',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#       'large': {'w': 1280, 'h': 720, 'resize': 'fit'}},
#      'source_status_id': 1321199597952192513,
#      'source_status_id_str': '1321199597952192513',
#      'source_user_id': 25073877,
#      'source_user_id_str': '25073877',
#      'video_info': {'aspect_ratio': [16, 9],
#       'duration_millis': 122816,
#       'variants': [{'bitrate': 2176000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/1321198287836172288/pu/vid/1280x720/bU5z5DbsWSGrpnL2.mp4?tag=10'},
#        {'bitrate': 256000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/1321198287836172288/pu/vid/480x270/jsLHmAZTwHYHi_KY.mp4?tag=10'},
#        {'content_type': 'application/x-mpegURL',
#         'url': 'https://video.twimg.com/ext_tw_video/1321198287836172288/pu/pl/DujVynW60offR6pl.m3u8?tag=10'},
#        {'bitrate': 832000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/1321198287836172288/pu/vid/640x360/GRxIsLSaTM2_W2S1.mp4?tag=10'}]},
#      'additional_media_info': {'monetizable': False,
#       'source_user': {'id': 25073877,
#        'id_str': '25073877',
#        'name': 'Donald J. Trump',
#        'screen_name': 'realDonaldTrump',
#        'location': 'Washington, DC',
#        'description': '45th President of the United States of America🇺🇸',
#        'url': 'https://t.co/8f9VFxztEJ',
#        'entities': {'url': {'urls': [{'url': 'https://t.co/8f9VFxztEJ',
#            'expanded_url': 'http://Vote.DonaldJTrump.com',
#            'display_url': 'Vote.DonaldJTrump.com',
#            'indices': [0, 23]}]},
#         'description': {'urls': []}},
#        'protected': False,
#        'followers_count': 87453818,
#        'friends_count': 50,
#        'listed_count': 122624,
#        'created_at': 'Wed Mar 18 13:46:38 +0000 2009',
#        'favourites_count': 6,
#        'utc_offset': None,
#        'time_zone': None,
#        'geo_enabled': True,
#        'verified': True,
#        'statuses_count': 58111,
#        'lang': None,
#        'contributors_enabled': False,
#        'is_translator': False,
#        'is_translation_enabled': True,
#        'profile_background_color': '6D5C18',
#        'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#        'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#        'profile_background_tile': True,
#        'profile_image_url': 'http://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#        'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#        'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25073877/1604214583',
#        'profile_link_color': '1B95E0',
#        'profile_sidebar_border_color': 'BDDCAD',
#        'profile_sidebar_fill_color': 'C5CEC0',
#        'profile_text_color': '333333',
#        'profile_use_background_image': True,
#        'has_extended_profile': False,
#        'default_profile': False,
#        'default_profile_image': False,
#        'following': False,
#        'follow_request_sent': False,
#        'notifications': False,
#        'translator_type': 'regular'}}}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 25073877,
#    'id_str': '25073877',
#    'name': 'Donald J. Trump',
#    'screen_name': 'realDonaldTrump',
#    'location': 'Washington, DC',
#    'description': '45th President of the United States of America🇺🇸',
#    'url': 'https://t.co/8f9VFxztEJ',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/8f9VFxztEJ',
#        'expanded_url': 'http://Vote.DonaldJTrump.com',
#        'display_url': 'Vote.DonaldJTrump.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 87453818,
#    'friends_count': 50,
#    'listed_count': 122624,
#    'created_at': 'Wed Mar 18 13:46:38 +0000 2009',
#    'favourites_count': 6,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 58111,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': '6D5C18',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25073877/1604214583',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': 'BDDCAD',
#    'profile_sidebar_fill_color': 'C5CEC0',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Tue Oct 27 21:18:25 +0000 2020',
#    'id': 1321199597952192513,
#    'id_str': '1321199597952192513',
#    'text': 'https://t.co/gsFSgh2KPc https://t.co/gs5RMGGhDR',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/gsFSgh2KPc',
#       'expanded_url': 'http://Vote.DonaldJTrump.com',
#       'display_url': 'Vote.DonaldJTrump.com',
#       'indices': [0, 23]}],
#     'media': [{'id': 1321198287836172288,
#       'id_str': '1321198287836172288',
#       'indices': [24, 47],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1321198287836172288/pu/img/GXvTxKjjCbraxJmT.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1321198287836172288/pu/img/GXvTxKjjCbraxJmT.jpg',
#       'url': 'https://t.co/gs5RMGGhDR',
#       'display_url': 'pic.twitter.com/gs5RMGGhDR',
#       'expanded_url': 'https://twitter.com/realDonaldTrump/status/1321199597952192513/video/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#        'large': {'w': 1280, 'h': 720, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1321198287836172288,
#       'id_str': '1321198287836172288',
#       'indices': [24, 47],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1321198287836172288/pu/img/GXvTxKjjCbraxJmT.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1321198287836172288/pu/img/GXvTxKjjCbraxJmT.jpg',
#       'url': 'https://t.co/gs5RMGGhDR',
#       'display_url': 'pic.twitter.com/gs5RMGGhDR',
#       'expanded_url': 'https://twitter.com/realDonaldTrump/status/1321199597952192513/video/1',
#       'type': 'video',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#        'large': {'w': 1280, 'h': 720, 'resize': 'fit'}},
#       'video_info': {'aspect_ratio': [16, 9],
#        'duration_millis': 122816,
#        'variants': [{'bitrate': 2176000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1321198287836172288/pu/vid/1280x720/bU5z5DbsWSGrpnL2.mp4?tag=10'},
#         {'bitrate': 256000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1321198287836172288/pu/vid/480x270/jsLHmAZTwHYHi_KY.mp4?tag=10'},
#         {'content_type': 'application/x-mpegURL',
#          'url': 'https://video.twimg.com/ext_tw_video/1321198287836172288/pu/pl/DujVynW60offR6pl.m3u8?tag=10'},
#         {'bitrate': 832000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1321198287836172288/pu/vid/640x360/GRxIsLSaTM2_W2S1.mp4?tag=10'}]},
#       'additional_media_info': {'monetizable': False}}]},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 25073877,
#     'id_str': '25073877',
#     'name': 'Donald J. Trump',
#     'screen_name': 'realDonaldTrump',
#     'location': 'Washington, DC',
#     'description': '45th President of the United States of America🇺🇸',
#     'url': 'https://t.co/8f9VFxztEJ',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/8f9VFxztEJ',
#         'expanded_url': 'http://Vote.DonaldJTrump.com',
#         'display_url': 'Vote.DonaldJTrump.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 87453818,
#     'friends_count': 50,
#     'listed_count': 122624,
#     'created_at': 'Wed Mar 18 13:46:38 +0000 2009',
#     'favourites_count': 6,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': True,
#     'statuses_count': 58111,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': True,
#     'profile_background_color': '6D5C18',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25073877/1604214583',
#     'profile_link_color': '1B95E0',
#     'profile_sidebar_border_color': 'BDDCAD',
#     'profile_sidebar_fill_color': 'C5CEC0',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'regular'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 11699,
#    'favorite_count': 50647,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'und'},
#   'is_quote_status': False,
#   'retweet_count': 11699,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'und'},
#  {'created_at': 'Tue Nov 03 19:50:22 +0000 2020',
#   'id': 1323714155967373312,
#   'id_str': '1323714155967373312',
#   'text': 'RT @realDonaldTrump: https://t.co/gsFSghkmdM https://t.co/Mu6grSAmV9',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'realDonaldTrump',
#      'name': 'Donald J. Trump',
#      'id': 25073877,
#      'id_str': '25073877',
#      'indices': [3, 19]}],
#    'urls': [{'url': 'https://t.co/gsFSghkmdM',
#      'expanded_url': 'http://Vote.DonaldJTrump.com',
#      'display_url': 'Vote.DonaldJTrump.com',
#      'indices': [21, 44]}],
#    'media': [{'id': 1321796045735604225,
#      'id_str': '1321796045735604225',
#      'indices': [45, 68],
#      'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1321796045735604225/pu/img/BxXTM-jU4vGp7puj.jpg',
#      'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1321796045735604225/pu/img/BxXTM-jU4vGp7puj.jpg',
#      'url': 'https://t.co/Mu6grSAmV9',
#      'display_url': 'pic.twitter.com/Mu6grSAmV9',
#      'expanded_url': 'https://twitter.com/realDonaldTrump/status/1321796173729013760/video/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#       'large': {'w': 1280, 'h': 720, 'resize': 'fit'}},
#      'source_status_id': 1321796173729013760,
#      'source_status_id_str': '1321796173729013760',
#      'source_user_id': 25073877,
#      'source_user_id_str': '25073877'}]},
#   'extended_entities': {'media': [{'id': 1321796045735604225,
#      'id_str': '1321796045735604225',
#      'indices': [45, 68],
#      'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1321796045735604225/pu/img/BxXTM-jU4vGp7puj.jpg',
#      'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1321796045735604225/pu/img/BxXTM-jU4vGp7puj.jpg',
#      'url': 'https://t.co/Mu6grSAmV9',
#      'display_url': 'pic.twitter.com/Mu6grSAmV9',
#      'expanded_url': 'https://twitter.com/realDonaldTrump/status/1321796173729013760/video/1',
#      'type': 'video',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#       'large': {'w': 1280, 'h': 720, 'resize': 'fit'}},
#      'source_status_id': 1321796173729013760,
#      'source_status_id_str': '1321796173729013760',
#      'source_user_id': 25073877,
#      'source_user_id_str': '25073877',
#      'video_info': {'aspect_ratio': [16, 9],
#       'duration_millis': 89216,
#       'variants': [{'bitrate': 2176000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/1321796045735604225/pu/vid/1280x720/vGH8Zi2dgDQLUus5.mp4?tag=10'},
#        {'bitrate': 256000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/1321796045735604225/pu/vid/480x270/NLgj1Xgs5Bhodydd.mp4?tag=10'},
#        {'bitrate': 832000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/1321796045735604225/pu/vid/640x360/gI_ZohY82uW-mVUB.mp4?tag=10'},
#        {'content_type': 'application/x-mpegURL',
#         'url': 'https://video.twimg.com/ext_tw_video/1321796045735604225/pu/pl/HRHI1TZ5QJaKPNz5.m3u8?tag=10'}]},
#      'additional_media_info': {'monetizable': False,
#       'source_user': {'id': 25073877,
#        'id_str': '25073877',
#        'name': 'Donald J. Trump',
#        'screen_name': 'realDonaldTrump',
#        'location': 'Washington, DC',
#        'description': '45th President of the United States of America🇺🇸',
#        'url': 'https://t.co/8f9VFxztEJ',
#        'entities': {'url': {'urls': [{'url': 'https://t.co/8f9VFxztEJ',
#            'expanded_url': 'http://Vote.DonaldJTrump.com',
#            'display_url': 'Vote.DonaldJTrump.com',
#            'indices': [0, 23]}]},
#         'description': {'urls': []}},
#        'protected': False,
#        'followers_count': 87453818,
#        'friends_count': 50,
#        'listed_count': 122624,
#        'created_at': 'Wed Mar 18 13:46:38 +0000 2009',
#        'favourites_count': 6,
#        'utc_offset': None,
#        'time_zone': None,
#        'geo_enabled': True,
#        'verified': True,
#        'statuses_count': 58111,
#        'lang': None,
#        'contributors_enabled': False,
#        'is_translator': False,
#        'is_translation_enabled': True,
#        'profile_background_color': '6D5C18',
#        'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#        'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#        'profile_background_tile': True,
#        'profile_image_url': 'http://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#        'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#        'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25073877/1604214583',
#        'profile_link_color': '1B95E0',
#        'profile_sidebar_border_color': 'BDDCAD',
#        'profile_sidebar_fill_color': 'C5CEC0',
#        'profile_text_color': '333333',
#        'profile_use_background_image': True,
#        'has_extended_profile': False,
#        'default_profile': False,
#        'default_profile_image': False,
#        'following': False,
#        'follow_request_sent': False,
#        'notifications': False,
#        'translator_type': 'regular'}}}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 25073877,
#    'id_str': '25073877',
#    'name': 'Donald J. Trump',
#    'screen_name': 'realDonaldTrump',
#    'location': 'Washington, DC',
#    'description': '45th President of the United States of America🇺🇸',
#    'url': 'https://t.co/8f9VFxztEJ',
# ...
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25073877/1604214583',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': 'BDDCAD',
#    'profile_sidebar_fill_color': 'C5CEC0',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 28565,
#   'favorite_count': 118990,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Mon Nov 02 21:30:19 +0000 2020',
#   'id': 1323376918620758022,
#   'id_str': '1323376918620758022',
#   'text': 'If I don’t sound like a typical Washington politician, it’s because I’m NOT a politician. If I don’t always play by… https://t.co/QZDxLPdACk',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/QZDxLPdACk',
#      'expanded_url': 'https://twitter.com/i/web/status/1323376918620758022',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 25073877,
#    'id_str': '25073877',
#    'name': 'Donald J. Trump',
#    'screen_name': 'realDonaldTrump',
#    'location': 'Washington, DC',
#    'description': '45th President of the United States of America🇺🇸',
#    'url': 'https://t.co/8f9VFxztEJ',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/8f9VFxztEJ',
#        'expanded_url': 'http://Vote.DonaldJTrump.com',
#        'display_url': 'Vote.DonaldJTrump.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 87453818,
#    'friends_count': 50,
#    'listed_count': 122624,
#    'created_at': 'Wed Mar 18 13:46:38 +0000 2009',
#    'favourites_count': 6,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 58111,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': '6D5C18',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25073877/1604214583',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': 'BDDCAD',
#    'profile_sidebar_fill_color': 'C5CEC0',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 12876,
#   'favorite_count': 61668,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Mon Nov 02 21:24:49 +0000 2020',
#   'id': 1323375536488521738,
#   'id_str': '1323375536488521738',
#   'text': 'Yesterday, I was thrilled to be endorsed by the Pittsburgh Post-Gazette, the first time the paper has endorsed a Re… https://t.co/iLiJ8DkyPp',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/iLiJ8DkyPp',
#      'expanded_url': 'https://twitter.com/i/web/status/1323375536488521738',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 25073877,
#    'id_str': '25073877',
#    'name': 'Donald J. Trump',
#    'screen_name': 'realDonaldTrump',
#    'location': 'Washington, DC',
#    'description': '45th President of the United States of America🇺🇸',
#    'url': 'https://t.co/8f9VFxztEJ',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/8f9VFxztEJ',
#        'expanded_url': 'http://Vote.DonaldJTrump.com',
#        'display_url': 'Vote.DonaldJTrump.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 87453818,
#    'friends_count': 50,
#    'listed_count': 122624,
#    'created_at': 'Wed Mar 18 13:46:38 +0000 2009',
#    'favourites_count': 6,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 58111,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': '6D5C18',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25073877/1604214583',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': 'BDDCAD',
#    'profile_sidebar_fill_color': 'C5CEC0',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 10077,
#   'favorite_count': 52110,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Mon Nov 02 21:24:03 +0000 2020',
#   'id': 1323375343571509249,
#   'id_str': '1323375343571509249',
#   'text': '...He was a cheerleader for NAFTA and China’s entry into the WTO. Pennsylvania lost half of its manufacturing jobs… https://t.co/wEkKdtYsz2',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/wEkKdtYsz2',
#      'expanded_url': 'https://twitter.com/i/web/status/1323375343571509249',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [116, 139]}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': 1323375339540762625,
#   'in_reply_to_status_id_str': '1323375339540762625',
#   'in_reply_to_user_id': 25073877,
#   'in_reply_to_user_id_str': '25073877',
#   'in_reply_to_screen_name': 'realDonaldTrump',
#   'user': {'id': 25073877,
#    'id_str': '25073877',
#    'name': 'Donald J. Trump',
#    'screen_name': 'realDonaldTrump',
#    'location': 'Washington, DC',
#    'description': '45th President of the United States of America🇺🇸',
#    'url': 'https://t.co/8f9VFxztEJ',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/8f9VFxztEJ',
#        'expanded_url': 'http://Vote.DonaldJTrump.com',
#        'display_url': 'Vote.DonaldJTrump.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 87453818,
#    'friends_count': 50,
#    'listed_count': 122624,
#    'created_at': 'Wed Mar 18 13:46:38 +0000 2009',
#    'favourites_count': 6,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 58111,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': '6D5C18',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25073877/1604214583',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': 'BDDCAD',
#    'profile_sidebar_fill_color': 'C5CEC0',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 10490,
#   'favorite_count': 50407,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Mon Nov 02 21:24:02 +0000 2020',
#   'id': 1323375339540762625,
#   'id_str': '1323375339540762625',
#   'text': 'Joe Biden is a globalist who spent 47 years outsourcing your jobs, opening your borders, and sacrificing American b… https://t.co/ZiehrFpjS7',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/ZiehrFpjS7',
#      'expanded_url': 'https://twitter.com/i/web/status/1323375339540762625',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 25073877,
#    'id_str': '25073877',
#    'name': 'Donald J. Trump',
#    'screen_name': 'realDonaldTrump',
#    'location': 'Washington, DC',
#    'description': '45th President of the United States of America🇺🇸',
#    'url': 'https://t.co/8f9VFxztEJ',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/8f9VFxztEJ',
#        'expanded_url': 'http://Vote.DonaldJTrump.com',
#        'display_url': 'Vote.DonaldJTrump.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 87453818,
#    'friends_count': 50,
#    'listed_count': 122624,
#    'created_at': 'Wed Mar 18 13:46:38 +0000 2009',
#    'favourites_count': 6,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 58111,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': '6D5C18',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25073877/1604214583',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': 'BDDCAD',
#    'profile_sidebar_fill_color': 'C5CEC0',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 24060,
#   'favorite_count': 107642,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Mon Nov 02 21:20:15 +0000 2020',
#   'id': 1323374386980753408,
#   'id_str': '1323374386980753408',
#   'text': 'Joe Biden’s plan to BAN FRACKING is an Economic DEATH SENTENCE for Pennsylvania. A vote for Biden is a vote to Ban… https://t.co/ozV3E0kJnY',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/ozV3E0kJnY',
#      'expanded_url': 'https://twitter.com/i/web/status/1323374386980753408',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [116, 139]}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 25073877,
#    'id_str': '25073877',
#    'name': 'Donald J. Trump',
#    'screen_name': 'realDonaldTrump',
#    'location': 'Washington, DC',
#    'description': '45th President of the United States of America🇺🇸',
#    'url': 'https://t.co/8f9VFxztEJ',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/8f9VFxztEJ',
#        'expanded_url': 'http://Vote.DonaldJTrump.com',
#        'display_url': 'Vote.DonaldJTrump.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 87453818,
#    'friends_count': 50,
#    'listed_count': 122624,
#    'created_at': 'Wed Mar 18 13:46:38 +0000 2009',
#    'favourites_count': 6,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 58111,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': '6D5C18',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25073877/1604214583',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': 'BDDCAD',
#    'profile_sidebar_fill_color': 'C5CEC0',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 8606,
#   'favorite_count': 38934,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'}]

# %%
# we'll take our results and turn them into a dataframe
results = pd.DataFrame({
    'name': [result['user']['name'] for result in tweet_results],
    'screen_name': [result['user']['screen_name'] for result in tweet_results],
    'text': [result['text'] for result in tweet_results],
    'retweets': [result['retweet_count'] for result in tweet_results],
    'favorites': [result['favorite_count'] for result in tweet_results],
    'id': [result['id_str'] for result in tweet_results]
})

print(f"API call brought in {results.shape[0]} new tweets")
results.head()
# Out:
# API call brought in 60 new tweets
#               name      screen_name  \
# 0  Donald J. Trump  realDonaldTrump
# 1  Donald J. Trump  realDonaldTrump
# 2  Donald J. Trump  realDonaldTrump
# 3  Donald J. Trump  realDonaldTrump
# 4  Donald J. Trump  realDonaldTrump
#
#                                                 text  retweets  favorites  \
# 0  RT @realDonaldTrump: VOTE! VOTE! VOTE!\nhttps:...    121165          0
# 1  RT @realDonaldTrump: https://t.co/gsFSghkmdM h...     14850          0
# 2  RT @realDonaldTrump: https://t.co/gsFSgh2KPc h...     11699          0
# 3  RT @realDonaldTrump: https://t.co/gsFSghkmdM h...     11580          0
# 4       RT @realDonaldTrump: https://t.co/voxNnIYMpe      8901          0
#
#                     id
# 0  1323714481353068546
# 1  1323714393184653323
# 2  1323714331922583556
# 3  1323714155967373312
# 4  1323714095225384962

# %% [markdown]
# ### Step 3:  Checking For New Values

# %%
# this does a check for new values
# left merge means 'tweets' is the dominant table
# indicator lets you know if the value was present in one of the tables or both
results.merge(tweets, on='id', how='left', indicator=True)
# Out:
#              name_x    screen_name_x  \
# 0   Donald J. Trump  realDonaldTrump
# 1   Donald J. Trump  realDonaldTrump
# 2   Donald J. Trump  realDonaldTrump
# 3   Donald J. Trump  realDonaldTrump
# 4   Donald J. Trump  realDonaldTrump
# 5   Donald J. Trump  realDonaldTrump
# 6   Donald J. Trump  realDonaldTrump
# 7   Donald J. Trump  realDonaldTrump
# 8   Donald J. Trump  realDonaldTrump
# 9   Donald J. Trump  realDonaldTrump
# 10  Donald J. Trump  realDonaldTrump
# 11  Donald J. Trump  realDonaldTrump
# 12  Donald J. Trump  realDonaldTrump
# 42  A vote for Joe Biden is a vote to extinguish a...     22340.0
# 43  I just signed an executive order to teach our ...     16994.0
# 44  Sleepy Joe Biden has vowed to ABOLISH the Amer...      9656.0
# 45                            https://t.co/yxoigJdsMz      7381.0
# 46  Just landed in Traverse City, Michigan. Big cr...     21609.0
# 47  ¡Mi #AmericanDreamPlan es una promesa para los...     17115.0
# 48  My #AmericanDreamPlan is a promise to Hispanic...     12927.0
# 49  RT @ClayTravis: I am voting for @realDonaldTru...      9836.0
# 50  As Christians throughout this great Country ce...     25303.0
# 51  For years you had a President who apologized f...     14790.0
# 52  With your VOTE, we will continue to cut your t...     13621.0
# 53  ...no future for America’s youth. A vote for B...      9563.0
# 54  Joe Biden is promising to delay the vaccine an...     28501.0
# 55  If I don’t sound like a typical Washington pol...     12853.0
# 56  Yesterday, I was thrilled to be endorsed by th...     10062.0
# 57  ...He was a cheerleader for NAFTA and China’s ...     10473.0
# 58  Joe Biden is a globalist who spent 47 years ou...     23978.0
# 59  Joe Biden’s plan to BAN FRACKING is an Economi...      8594.0
#
#     favorites_y     _merge
# 0           NaN  left_only
# 1           NaN  left_only
# 2           NaN  left_only
# 3           NaN  left_only
# 4           NaN  left_only
# 5           NaN  left_only
# 6       47177.0       both
# 7       44040.0       both
# 8           0.0       both
# 9      199959.0       both
# 10     128350.0       both
# 11     101397.0       both
# 12     556088.0       both
# 13          0.0       both
# 14          0.0       both
# 15      95538.0       both
# 16          0.0       both
# 17      91995.0       both
# 18          0.0       both
# 19     253027.0       both
# 20      43488.0       both
# 21      51155.0       both
# 22      40323.0       both
# 23      41106.0       both
# 24      66436.0       both
# 25     219963.0       both
# 26      98805.0       both
# 27      70754.0       both
# 28      59871.0       both
# 29      89439.0       both
# 30      85116.0       both
# 31      41651.0       both
# 32      39321.0       both
# 33      54222.0       both
# 34          0.0       both
# 35      53101.0       both
# 36          0.0       both
# 37      75032.0       both
# 38      81611.0       both
# 39      72771.0       both
# 40     173958.0       both
# 41     121019.0       both
# 42     106720.0       both
# 43      86957.0       both
# 44      43830.0       both
# 45      40846.0       both
# 46     211181.0       both
# 47      80408.0       both
# 48      63460.0       both
# 49          0.0       both
# 50     137996.0       both
# 51      66932.0       both
# 52      64776.0       both
# 53      46888.0       both
# 54     118622.0       both
# 55      61470.0       both
# 56      51949.0       both
# 57      50280.0       both
# 58     107210.0       both
# 59      38817.0       both

# %%
# we'll save the variable
merged_df = results.merge(tweets, on='id', how='left', indicator=True)

# %%
# select the values that are left_only in the _merge column -- these are new values
print(f"Found {merged_df[merged_df._merge == 'left_only'].shape[0]} new tweets not currently in the database")
merged_df[merged_df._merge == 'left_only']
# Out:
# Found 6 new tweets not currently in the database
#             name_x    screen_name_x  \
# 0  Donald J. Trump  realDonaldTrump
# 1  Donald J. Trump  realDonaldTrump
# 2  Donald J. Trump  realDonaldTrump
# 3  Donald J. Trump  realDonaldTrump
# 4  Donald J. Trump  realDonaldTrump
# 5  Donald J. Trump  realDonaldTrump
#
#                                               text_x  retweets_x  favorites_x  \
# 0  RT @realDonaldTrump: VOTE! VOTE! VOTE!\nhttps:...      121165            0
# 1  RT @realDonaldTrump: https://t.co/gsFSghkmdM h...       14850            0
# 2  RT @realDonaldTrump: https://t.co/gsFSgh2KPc h...       11699            0
# 3  RT @realDonaldTrump: https://t.co/gsFSghkmdM h...       11580            0
# 4       RT @realDonaldTrump: https://t.co/voxNnIYMpe        8901            0
# 5  RT @realDonaldTrump: https://t.co/gsFSghkmdM h...       13069            0
#
#                     id name_y screen_name_y text_y  retweets_y  favorites_y  \
# 0  1323714481353068546    NaN           NaN    NaN         NaN          NaN
# 1  1323714393184653323    NaN           NaN    NaN         NaN          NaN
# 2  1323714331922583556    NaN           NaN    NaN         NaN          NaN
# 3  1323714155967373312    NaN           NaN    NaN         NaN          NaN
# 4  1323714095225384962    NaN           NaN    NaN         NaN          NaN
# 5  1323713956280754182    NaN           NaN    NaN         NaN          NaN
#
#       _merge
# 0  left_only
# 1  left_only
# 2  left_only
# 3  left_only
# 4  left_only
# 5  left_only

# %%
# get the index positions where this value is True
merged_df[merged_df._merge == 'left_only'].index
# Out:
# Int64Index([0, 1, 2, 3, 4, 5], dtype='int64')

# %%
results.index
# Out:
# RangeIndex(start=0, stop=60, step=1)

# %%
# use these values to look up tweets in the original results df
idx = merged_df[merged_df._merge == 'left_only'].index
# and these are our new tweets
results.iloc[idx]
# Out:
#               name      screen_name  \
# 0  Donald J. Trump  realDonaldTrump
# 1  Donald J. Trump  realDonaldTrump
# 2  Donald J. Trump  realDonaldTrump
# 3  Donald J. Trump  realDonaldTrump
# 4  Donald J. Trump  realDonaldTrump
# 5  Donald J. Trump  realDonaldTrump
#
#                                                 text  retweets  favorites  \
# 0  RT @realDonaldTrump: VOTE! VOTE! VOTE!\nhttps:...    121165          0
# 1  RT @realDonaldTrump: https://t.co/gsFSghkmdM h...     14850          0
# 2  RT @realDonaldTrump: https://t.co/gsFSgh2KPc h...     11699          0
# 3  RT @realDonaldTrump: https://t.co/gsFSghkmdM h...     11580          0
# 4       RT @realDonaldTrump: https://t.co/voxNnIYMpe      8901          0
# 5  RT @realDonaldTrump: https://t.co/gsFSghkmdM h...     13069          0
#
#                     id
# 0  1323714481353068546
# 1  1323714393184653323
# 2  1323714331922583556
# 3  1323714155967373312
# 4  1323714095225384962
# 5  1323713956280754182

# %%
# and now we'll connect to the database and add in the values
with engine.connect() as connection:
    # declare data types for the db -- not necessary but a useful step if you are doing this the first time
    dtypes = {
        'name': types.String(length=65535),
        'screen_name': types.String(length=65535),
        'text': types.String(length=65535),
        'retweets': types.Integer(),
        'favorites': types.Integer(),
        'id': types.String(length=65535)
    }
    print("Adding values to database")
    try:
        results.iloc[idx].to_sql('tweets', con=connection, index=False, if_exists='append', dtype=dtypes)
        print("Successful")
    except Exception as e:
        print("Could not add results to the database.", e)
# Out:
# Adding values to database
# Successful
