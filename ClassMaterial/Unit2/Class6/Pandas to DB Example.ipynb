# %% [markdown]
# ### Connecting Pandas to a Database
#
# This notebook will walk us through how to use pandas to interact with a database, and then query an API and add new values to it.
#
# Running this code continuously will allow us to programmatically collect a unique data source.

# %%
import pandas as pd
import numpy as np
# you will need to import this -- pip install SQLAlchemy
from sqlalchemy import create_engine, types
# you will need to import this -- pip install mysql-connector-python
import mysql.connector
import requests
# you will need to install this  -- pip install requests-oauthlib
from requests_oauthlib import OAuth1

# %% [markdown]
# ### Step 1:  Fetching the Data From the Database

# %%
# we'll create a dictionary to store all of our database information
df_dict = {
    'connector': 'mysql+mysqlconnector',
    'username' : 'dat1019',
    'password' : 'dat1019password',
    'server'   : 'dat-10-19.cfvn8ddij95j.us-east-1.rds.amazonaws.com',
    'port'     : '3306',
    'database' : 'dat1019'
}

# %%
# this string contains all the information
connection_string = f"{df_dict['connector']}://{df_dict['username']}:{df_dict['password']}@{df_dict['server']}:{df_dict['port']}/{df_dict['database']}"

# %%
connection_string
# Out:
# 'mysql+mysqlconnector://dat1019:dat1019password@dat-10-19.cfvn8ddij95j.us-east-1.rds.amazonaws.com:3306/dat1019'

# %%
# this is what we need to connect to our database
engine = create_engine(connection_string)

# %%
# we'll now connect to the database and pull in the info
with engine.connect() as connection:
    tweets = pd.read_sql_query("SELECT * FROM tweets", con=connection)

# %%
# let's look at our results
tweets.head()
# Out:
#               name      screen_name  \
# 0  Donald J. Trump  realDonaldTrump
# 1  Donald J. Trump  realDonaldTrump
# 2  Donald J. Trump  realDonaldTrump
# 3  Donald J. Trump  realDonaldTrump
# 4  Donald J. Trump  realDonaldTrump
#
#                                                 text  retweets  favorites  \
# 0  RT @realDonaldTrump: VOTE! VOTE! VOTE!\nhttps:...    117124          0
# 1                            https://t.co/zX4bqgtWqH     10186      47177
# 2                            https://t.co/SMaOF79kPV     10806      44040
# 3  RT @BarstoolNewsN: The Amish are not playing a...     17887          0
# 4  A parade for me in Nigeria, a great honor! htt...     39398     199959
#
#                     id
# 0  1323692146147340299
# 1  1323692020880297986
# 2  1323691984989622272
# 3  1323684790894297089
# 4  1323680963310866435

# %%
# we will turn this column into a string -- useful for later processing
tweets['id'] = tweets.id.astype(str)

# %% [markdown]
# ### Step 2:  Getting API Data

# %%
# authorization information for the Twitter API
tokens = OAuth1('NOZHm1aLT1AVmchGbCmiZOAga', 'nPyaYCt8L7ymqGZtU8EqC0a2ypI9aSJgVNIhtoZ0wGsaf3BJw9',
                '1079981876864008192-AlhO4yOa06oW2sXZpLpWPwnOxEERYS', 'o3E0AsKJfDoTBk77UQYExzOG7E46jPYvpWNGAKsD6lUBY')

# %%
# the api endpoint we'll ping to get our API results
base_url = 'https://api.twitter.com/1.1/statuses/user_timeline.json?screen_name=realDonaldTrump&count=200'

# %%
# this is our list of dictionaries that contains Donald Trump's tweets
tweet_results = requests.get(base_url, auth=tokens).json()

# %%
# here's our resulting dictionary
tweet_results
# Out:
# [{'created_at': 'Wed Nov 04 23:27:55 +0000 2020',
#   'id': 1324131291135168512,
#   'id_str': '1324131291135168512',
#   'text': 'RT @GOPLeader: The Republican coalition is bigger, more diverse, and more energetic than ever before—thanks to President @realDonaldTrump.…',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'GOPLeader',
#      'name': 'Kevin McCarthy',
#      'id': 19739126,
#      'id_str': '19739126',
#      'indices': [3, 13]},
#     {'screen_name': 'realDonaldTrump',
#      'name': 'Donald J. Trump',
#      'id': 25073877,
#      'id_str': '25073877',
#      'indices': [121, 137]}],
#    'urls': []},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 25073877,
#    'id_str': '25073877',
#    'name': 'Donald J. Trump',
#    'screen_name': 'realDonaldTrump',
#    'location': 'Washington, DC',
#    'description': '45th President of the United States of America🇺🇸',
#    'url': 'https://t.co/8f9VFxztEJ',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/8f9VFxztEJ',
#        'expanded_url': 'http://Vote.DonaldJTrump.com',
#        'display_url': 'Vote.DonaldJTrump.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 88010918,
#    'friends_count': 50,
#    'listed_count': 123365,
#    'created_at': 'Wed Mar 18 13:46:38 +0000 2009',
#    'favourites_count': 6,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 58127,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': '6D5C18',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25073877/1604214583',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': 'BDDCAD',
#    'profile_sidebar_fill_color': 'C5CEC0',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Nov 04 17:17:31 +0000 2020',
#    'id': 1324038077342429185,
#    'id_str': '1324038077342429185',
#    'text': 'The Republican coalition is bigger, more diverse, and more energetic than ever before—thanks to President… https://t.co/STuSQm4B7w',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/STuSQm4B7w',
#       'expanded_url': 'https://twitter.com/i/web/status/1324038077342429185',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [107, 130]}]},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 19739126,
#     'id_str': '19739126',
#     'name': 'Kevin McCarthy',
#     'screen_name': 'GOPLeader',
#     'location': 'Bakersfield, CA',
#     'description': "Republican Leader and Representative of California's 23rd District in the House of Representatives.",
#     'url': 'https://t.co/JyoaR3z3Zi',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/JyoaR3z3Zi',
#         'expanded_url': 'http://commitmenttoamerica.com/',
#         'display_url': 'commitmenttoamerica.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1072740,
#     'friends_count': 1392,
#     'listed_count': 5607,
#     'created_at': 'Thu Jan 29 22:28:48 +0000 2009',
#     'favourites_count': 1923,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': True,
#     'statuses_count': 14885,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '3B94D9',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1144683452064833536/fZbuxrtg_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1144683452064833536/fZbuxrtg_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/19739126/1582230846',
#     'profile_link_color': '0A2644',
#     'profile_sidebar_border_color': 'FF0000',
#     'profile_sidebar_fill_color': 'FFFFFF',
#     'profile_text_color': '122C73',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 3250,
#    'favorite_count': 15206,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 3250,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Nov 04 23:24:59 +0000 2020',
#   'id': 1324130551234727936,
#   'id_str': '1324130551234727936',
#   'text': 'Our lawyers have asked for “meaningful access”, but what good does that do? The damage has already been done to the… https://t.co/HZ6WfKeLez',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/HZ6WfKeLez',
#      'expanded_url': 'https://twitter.com/i/web/status/1324130551234727936',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 25073877,
#    'id_str': '25073877',
#    'name': 'Donald J. Trump',
#    'screen_name': 'realDonaldTrump',
#    'location': 'Washington, DC',
#    'description': '45th President of the United States of America🇺🇸',
#    'url': 'https://t.co/8f9VFxztEJ',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/8f9VFxztEJ',
#        'expanded_url': 'http://Vote.DonaldJTrump.com',
#        'display_url': 'Vote.DonaldJTrump.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 88010918,
#    'friends_count': 50,
#    'listed_count': 123365,
#    'created_at': 'Wed Mar 18 13:46:38 +0000 2009',
#    'favourites_count': 6,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 58127,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': '6D5C18',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25073877/1604214583',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': 'BDDCAD',
#    'profile_sidebar_fill_color': 'C5CEC0',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 24048,
#   'favorite_count': 114338,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Nov 04 21:56:11 +0000 2020',
#   'id': 1324108206801563650,
#   'id_str': '1324108206801563650',
#   'text': '.....there was a large number of secretly dumped ballots as has been widely reported!',
#   'truncated': False,
#   'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': 1324108200141082624,
#   'in_reply_to_status_id_str': '1324108200141082624',
#   'in_reply_to_user_id': 25073877,
#   'in_reply_to_user_id_str': '25073877',
#   'in_reply_to_screen_name': 'realDonaldTrump',
#   'user': {'id': 25073877,
#    'id_str': '25073877',
#    'name': 'Donald J. Trump',
#    'screen_name': 'realDonaldTrump',
#    'location': 'Washington, DC',
#    'description': '45th President of the United States of America🇺🇸',
#    'url': 'https://t.co/8f9VFxztEJ',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/8f9VFxztEJ',
#        'expanded_url': 'http://Vote.DonaldJTrump.com',
#        'display_url': 'Vote.DonaldJTrump.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 88010918,
#    'friends_count': 50,
#    'listed_count': 123365,
#    'created_at': 'Wed Mar 18 13:46:38 +0000 2009',
#    'favourites_count': 6,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 58127,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': '6D5C18',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25073877/1604214583',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': 'BDDCAD',
#    'profile_sidebar_fill_color': 'C5CEC0',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Nov 04 21:56:10 +0000 2020',
#   'id': 1324108200141082624,
#   'id_str': '1324108200141082624',
#   'text': 'We have claimed, for Electoral Vote purposes, the Commonwealth of Pennsylvania (which won’t allow legal observers)… https://t.co/tyDx2FcTzX',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/tyDx2FcTzX',
#      'expanded_url': 'https://twitter.com/i/web/status/1324108200141082624',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [116, 139]}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 25073877,
#    'id_str': '25073877',
#    'name': 'Donald J. Trump',
#    'screen_name': 'realDonaldTrump',
#    'location': 'Washington, DC',
#    'description': '45th President of the United States of America🇺🇸',
#    'url': 'https://t.co/8f9VFxztEJ',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/8f9VFxztEJ',
#        'expanded_url': 'http://Vote.DonaldJTrump.com',
#        'display_url': 'Vote.DonaldJTrump.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 88010918,
#    'friends_count': 50,
#    'listed_count': 123365,
#    'created_at': 'Wed Mar 18 13:46:38 +0000 2009',
#    'favourites_count': 6,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 58127,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': '6D5C18',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25073877/1604214583',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': 'BDDCAD',
#    'profile_sidebar_fill_color': 'C5CEC0',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 49889,
#   'favorite_count': 207707,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Nov 04 18:52:32 +0000 2020',
#   'id': 1324061986779504642,
#   'id_str': '1324061986779504642',
#   'text': 'We are winning Pennsylvania big, but the PA Secretary of State just announced that there are “Millions of ballots left to be counted.”',
#   'truncated': False,
#   'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 25073877,
#    'id_str': '25073877',
#    'name': 'Donald J. Trump',
#    'screen_name': 'realDonaldTrump',
#    'location': 'Washington, DC',
#    'description': '45th President of the United States of America🇺🇸',
#    'url': 'https://t.co/8f9VFxztEJ',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/8f9VFxztEJ',
#        'expanded_url': 'http://Vote.DonaldJTrump.com',
#        'display_url': 'Vote.DonaldJTrump.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 88010918,
#    'friends_count': 50,
#    'listed_count': 123365,
#    'created_at': 'Wed Mar 18 13:46:38 +0000 2009',
#    'favourites_count': 6,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 58127,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': '6D5C18',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25073877/1604214583',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': 'BDDCAD',
#    'profile_sidebar_fill_color': 'C5CEC0',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 52149,
#   'favorite_count': 292330,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Nov 04 18:43:43 +0000 2020',
#   'id': 1324059767581671425,
#   'id_str': '1324059767581671425',
#   'text': 'Wow! It looks like Michigan has now found the ballots necessary to keep a wonderful young man, John James, out of t… https://t.co/YRUDx8kOAj',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/YRUDx8kOAj',
#      'expanded_url': 'https://twitter.com/i/web/status/1324059767581671425',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 25073877,
#    'id_str': '25073877',
#    'name': 'Donald J. Trump',
#    'screen_name': 'realDonaldTrump',
#    'location': 'Washington, DC',
#    'description': '45th President of the United States of America🇺🇸',
#    'url': 'https://t.co/8f9VFxztEJ',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/8f9VFxztEJ',
#        'expanded_url': 'http://Vote.DonaldJTrump.com',
#        'display_url': 'Vote.DonaldJTrump.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 88010918,
#    'friends_count': 50,
#    'listed_count': 123365,
#    'created_at': 'Wed Mar 18 13:46:38 +0000 2009',
#    'favourites_count': 6,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 58127,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': '6D5C18',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25073877/1604214583',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': 'BDDCAD',
#    'profile_sidebar_fill_color': 'C5CEC0',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 62856,
#   'favorite_count': 316627,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Nov 04 17:01:15 +0000 2020',
#   'id': 1324033983882166272,
#   'id_str': '1324033983882166272',
#   'text': 'They are working hard to make up 500,000 vote advantage in Pennsylvania disappear — ASAP. Likewise, Michigan and others!',
#   'truncated': False,
#   'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 25073877,
#    'id_str': '25073877',
#    'name': 'Donald J. Trump',
#    'screen_name': 'realDonaldTrump',
#    'location': 'Washington, DC',
#    'description': '45th President of the United States of America🇺🇸',
#    'url': 'https://t.co/8f9VFxztEJ',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/8f9VFxztEJ',
#        'expanded_url': 'http://Vote.DonaldJTrump.com',
#        'display_url': 'Vote.DonaldJTrump.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 88010918,
#    'friends_count': 50,
#    'listed_count': 123365,
#    'created_at': 'Wed Mar 18 13:46:38 +0000 2009',
#    'favourites_count': 6,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 58127,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': '6D5C18',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25073877/1604214583',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': 'BDDCAD',
#    'profile_sidebar_fill_color': 'C5CEC0',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Nov 04 16:55:31 +0000 2020',
#   'id': 1324032541544927233,
#   'id_str': '1324032541544927233',
#   'text': 'They are finding Biden votes all over the place — in Pennsylvania, Wisconsin, and Michigan. So bad for our Country!',
#   'truncated': False,
#   'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 25073877,
#    'id_str': '25073877',
#    'name': 'Donald J. Trump',
#    'screen_name': 'realDonaldTrump',
#    'location': 'Washington, DC',
#    'description': '45th President of the United States of America🇺🇸',
#    'url': 'https://t.co/8f9VFxztEJ',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/8f9VFxztEJ',
#        'expanded_url': 'http://Vote.DonaldJTrump.com',
#        'display_url': 'Vote.DonaldJTrump.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 88010918,
#    'friends_count': 50,
#    'listed_count': 123365,
#    'created_at': 'Wed Mar 18 13:46:38 +0000 2009',
#    'favourites_count': 6,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 58127,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': '6D5C18',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25073877/1604214583',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': 'BDDCAD',
#    'profile_sidebar_fill_color': 'C5CEC0',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 87800,
#   'favorite_count': 495294,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Nov 04 15:35:15 +0000 2020',
#   'id': 1324012341458075648,
#   'id_str': '1324012341458075648',
#   'text': 'WHAT IS THIS ALL ABOUT? https://t.co/6487pYLZnL',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/6487pYLZnL',
#      'expanded_url': 'https://twitter.com/mattwalshblog/status/1323999569466789889',
#      'display_url': 'twitter.com/mattwalshblog/…',
#      'indices': [24, 47]}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 25073877,
#    'id_str': '25073877',
#    'name': 'Donald J. Trump',
#    'screen_name': 'realDonaldTrump',
#    'location': 'Washington, DC',
#    'description': '45th President of the United States of America🇺🇸',
#    'url': 'https://t.co/8f9VFxztEJ',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/8f9VFxztEJ',
#        'expanded_url': 'http://Vote.DonaldJTrump.com',
#        'display_url': 'Vote.DonaldJTrump.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 88010918,
#    'friends_count': 50,
#    'listed_count': 123365,
#    'created_at': 'Wed Mar 18 13:46:38 +0000 2009',
#    'favourites_count': 6,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 58127,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': '6D5C18',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25073877/1604214583',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': 'BDDCAD',
#    'profile_sidebar_fill_color': 'C5CEC0',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': True,
#   'quoted_status_id': 1323999569466789889,
#   'quoted_status_id_str': '1323999569466789889',
#   'quoted_status': {'created_at': 'Wed Nov 04 14:44:30 +0000 2020',
#    'id': 1323999569466789889,
#    'id_str': '1323999569466789889',
#    'text': "This is reason enough to go to court. No honest person can look at this and say it's normal and unconcerning. https://t.co/CguBRGCRLD",
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/CguBRGCRLD',
#       'expanded_url': 'https://twitter.com/MattMackowiak/status/1323992377380450309',
#       'display_url': 'twitter.com/MattMackowiak/…',
#       'indices': [110, 133]}]},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1500129642,
#     'id_str': '1500129642',
#     'name': 'Matt Walsh',
#     'screen_name': 'MattWalshBlog',
#     'location': '',
#     'description': 'theocratic fascist, tyrant, beekeeper',
#     'url': 'https://t.co/OeRdAHUUXH',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/OeRdAHUUXH',
#         'expanded_url': 'https://m.youtube.com/MattWalsh',
#         'display_url': 'm.youtube.com/MattWalsh',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 503130,
#     'friends_count': 507,
#     'listed_count': 2891,
#     'created_at': 'Tue Jun 11 03:17:16 +0000 2013',
#     'favourites_count': 0,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': True,
#     'statuses_count': 46462,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1321067275076685829/B-QUfF-b_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1321067275076685829/B-QUfF-b_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1500129642/1602031710',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': True,
#    'quoted_status_id': 1323992377380450309,
#    'quoted_status_id_str': '1323992377380450309',
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'retweet_count': 39988,
#   'favorite_count': 144104,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Nov 04 15:17:14 +0000 2020',
#   'id': 1324007806694023169,
#   'id_str': '1324007806694023169',
#   'text': 'How come every time they count Mail-In ballot dumps they are so devastating in their percentage and power of destruction?',
#   'truncated': False,
#   'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 25073877,
#    'id_str': '25073877',
#    'name': 'Donald J. Trump',
#    'screen_name': 'realDonaldTrump',
#    'location': 'Washington, DC',
#    'description': '45th President of the United States of America🇺🇸',
#    'url': 'https://t.co/8f9VFxztEJ',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/8f9VFxztEJ',
#        'expanded_url': 'http://Vote.DonaldJTrump.com',
#        'display_url': 'Vote.DonaldJTrump.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 88010918,
#    'friends_count': 50,
#    'listed_count': 123365,
#    'created_at': 'Wed Mar 18 13:46:38 +0000 2009',
#    'favourites_count': 6,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 58127,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': '6D5C18',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25073877/1604214583',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': 'BDDCAD',
#    'profile_sidebar_fill_color': 'C5CEC0',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 78643,
#   'favorite_count': 466262,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Nov 04 15:04:04 +0000 2020',
#   'id': 1324004491612618752,
#   'id_str': '1324004491612618752',
#   'text': 'Last night I was leading, often solidly, in many key States, in almost all instances Democrat run &amp; controlled. The… https://t.co/iHjUvC3kMO',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/iHjUvC3kMO',
#      'expanded_url': 'https://twitter.com/i/web/status/1324004491612618752',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [121, 144]}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 25073877,
#    'id_str': '25073877',
#    'name': 'Donald J. Trump',
#    'screen_name': 'realDonaldTrump',
#    'location': 'Washington, DC',
#    'description': '45th President of the United States of America🇺🇸',
#    'url': 'https://t.co/8f9VFxztEJ',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/8f9VFxztEJ',
#        'expanded_url': 'http://Vote.DonaldJTrump.com',
#        'display_url': 'Vote.DonaldJTrump.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 88010918,
#    'friends_count': 50,
#    'listed_count': 123365,
#    'created_at': 'Wed Mar 18 13:46:38 +0000 2009',
#    'favourites_count': 6,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 58127,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': '6D5C18',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25073877/1604214583',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': 'BDDCAD',
#    'profile_sidebar_fill_color': 'C5CEC0',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Nov 04 07:25:41 +0000 2020',
#   'id': 1323889136571437056,
#   'id_str': '1323889136571437056',
#   'text': 'RT @TeamTrump: LIVE: President Donald J Trump https://t.co/J7hhaUPUf0',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'TeamTrump',
#      'name': 'Team Trump (Text VOTE to 88022)',
#      'id': 729676086632656900,
#      'id_str': '729676086632656900',
#      'indices': [3, 13]}],
#    'urls': [{'url': 'https://t.co/J7hhaUPUf0',
#      'expanded_url': 'https://twitter.com/i/broadcasts/1BdxYnZBLqZKX',
#      'display_url': 'twitter.com/i/broadcasts/1…',
#      'indices': [46, 69]}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 25073877,
#    'id_str': '25073877',
#    'name': 'Donald J. Trump',
#    'screen_name': 'realDonaldTrump',
#    'location': 'Washington, DC',
#    'description': '45th President of the United States of America🇺🇸',
#    'url': 'https://t.co/8f9VFxztEJ',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/8f9VFxztEJ',
#        'expanded_url': 'http://Vote.DonaldJTrump.com',
#        'display_url': 'Vote.DonaldJTrump.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 88010918,
#    'friends_count': 50,
#    'listed_count': 123365,
#    'created_at': 'Wed Mar 18 13:46:38 +0000 2009',
#    'favourites_count': 6,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 58127,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': '6D5C18',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25073877/1604214583',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': 'BDDCAD',
#    'profile_sidebar_fill_color': 'C5CEC0',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Nov 04 07:21:42 +0000 2020',
#    'id': 1323888133390348288,
#    'id_str': '1323888133390348288',
#    'text': 'LIVE: President Donald J Trump https://t.co/J7hhaUPUf0',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/J7hhaUPUf0',
#       'expanded_url': 'https://twitter.com/i/broadcasts/1BdxYnZBLqZKX',
#       'display_url': 'twitter.com/i/broadcasts/1…',
#       'indices': [31, 54]}]},
#    'source': '<a href="https://studio.twitter.com" rel="nofollow">Twitter Media Studio</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 729676086632656900,
#     'id_str': '729676086632656900',
#     'name': 'Team Trump (Text VOTE to 88022)',
#     'screen_name': 'TeamTrump',
#     'location': 'USA',
#     'description': 'The official Twitter account for the Trump Campaign. Together, we will MAKE AMERICA GREAT AGAIN! 🇺🇸',
#     'url': 'https://t.co/mZB2hymxC9',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/mZB2hymxC9',
#         'expanded_url': 'http://www.DonaldJTrump.com',
#         'display_url': 'DonaldJTrump.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 2361934,
#     'friends_count': 132,
#     'listed_count': 4659,
#     'created_at': 'Mon May 09 14:15:10 +0000 2016',
#     'favourites_count': 3522,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': True,
#     'statuses_count': 29730,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/745768799849308160/KrZhjkpH_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/745768799849308160/KrZhjkpH_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/729676086632656900/1588979102',
#     'profile_link_color': 'CB0606',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 37401,
#    'favorite_count': 163383,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 37401,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Nov 04 05:49:04 +0000 2020',
#   'id': 1323864823680126977,
#   'id_str': '1323864823680126977',
#   'text': 'We are up BIG, but they are trying to STEAL the Election. We will never let them do it. Votes cannot be cast after the Polls are closed!',
#   'truncated': False,
#   'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 25073877,
#    'id_str': '25073877',
#    'name': 'Donald J. Trump',
#    'screen_name': 'realDonaldTrump',
#    'location': 'Washington, DC',
#    'description': '45th President of the United States of America🇺🇸',
#    'url': 'https://t.co/8f9VFxztEJ',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/8f9VFxztEJ',
#        'expanded_url': 'http://Vote.DonaldJTrump.com',
#        'display_url': 'Vote.DonaldJTrump.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 88010918,
#    'friends_count': 50,
#    'listed_count': 123365,
#    'created_at': 'Wed Mar 18 13:46:38 +0000 2009',
#    'favourites_count': 6,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 58127,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': '6D5C18',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25073877/1604214583',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': 'BDDCAD',
#    'profile_sidebar_fill_color': 'C5CEC0',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Nov 04 05:45:53 +0000 2020',
#   'id': 1323864021167198209,
#   'id_str': '1323864021167198209',
#   'text': 'I will be making a statement tonight. A big WIN!',
#   'truncated': False,
#   'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 25073877,
#    'id_str': '25073877',
#    'name': 'Donald J. Trump',
#    'screen_name': 'realDonaldTrump',
#    'location': 'Washington, DC',
#    'description': '45th President of the United States of America🇺🇸',
#    'url': 'https://t.co/8f9VFxztEJ',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/8f9VFxztEJ',
#        'expanded_url': 'http://Vote.DonaldJTrump.com',
#        'display_url': 'Vote.DonaldJTrump.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 88010918,
#    'friends_count': 50,
#    'listed_count': 123365,
#    'created_at': 'Wed Mar 18 13:46:38 +0000 2009',
#    'favourites_count': 6,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 58127,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': '6D5C18',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
# ...
#          'url': 'https://video.twimg.com/ext_tw_video/1321796045735604225/pu/vid/480x270/NLgj1Xgs5Bhodydd.mp4?tag=10'},
#         {'bitrate': 832000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1321796045735604225/pu/vid/640x360/gI_ZohY82uW-mVUB.mp4?tag=10'},
#         {'content_type': 'application/x-mpegURL',
#          'url': 'https://video.twimg.com/ext_tw_video/1321796045735604225/pu/pl/HRHI1TZ5QJaKPNz5.m3u8?tag=10'}]},
#       'additional_media_info': {'monetizable': False}}]},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 25073877,
#     'id_str': '25073877',
#     'name': 'Donald J. Trump',
#     'screen_name': 'realDonaldTrump',
#     'location': 'Washington, DC',
#     'description': '45th President of the United States of America🇺🇸',
#     'url': 'https://t.co/8f9VFxztEJ',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/8f9VFxztEJ',
#         'expanded_url': 'http://Vote.DonaldJTrump.com',
#         'display_url': 'Vote.DonaldJTrump.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 88010918,
#     'friends_count': 50,
#     'listed_count': 123365,
#     'created_at': 'Wed Mar 18 13:46:38 +0000 2009',
#     'favourites_count': 6,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': True,
#     'statuses_count': 58127,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': True,
#     'profile_background_color': '6D5C18',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25073877/1604214583',
#     'profile_link_color': '1B95E0',
#     'profile_sidebar_border_color': 'BDDCAD',
#     'profile_sidebar_fill_color': 'C5CEC0',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'regular'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 14936,
#    'favorite_count': 72886,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'und'},
#   'is_quote_status': False,
#   'retweet_count': 14936,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'und'},
#  {'created_at': 'Tue Nov 03 19:50:08 +0000 2020',
#   'id': 1323714095225384962,
#   'id_str': '1323714095225384962',
#   'text': 'RT @realDonaldTrump: https://t.co/voxNnIYMpe',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'realDonaldTrump',
#      'name': 'Donald J. Trump',
#      'id': 25073877,
#      'id_str': '25073877',
#      'indices': [3, 19]}],
#    'urls': [],
#    'media': [{'id': 1322208189669023750,
#      'id_str': '1322208189669023750',
#      'indices': [21, 44],
#      'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1322208189669023750/pu/img/xR-sX_dlfysy_orJ.jpg',
#      'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1322208189669023750/pu/img/xR-sX_dlfysy_orJ.jpg',
#      'url': 'https://t.co/voxNnIYMpe',
#      'display_url': 'pic.twitter.com/voxNnIYMpe',
#      'expanded_url': 'https://twitter.com/realDonaldTrump/status/1322209177268154375/video/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#       'large': {'w': 1280, 'h': 720, 'resize': 'fit'}},
#      'source_status_id': 1322209177268154375,
#      'source_status_id_str': '1322209177268154375',
#      'source_user_id': 25073877,
#      'source_user_id_str': '25073877'}]},
#   'extended_entities': {'media': [{'id': 1322208189669023750,
#      'id_str': '1322208189669023750',
#      'indices': [21, 44],
#      'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1322208189669023750/pu/img/xR-sX_dlfysy_orJ.jpg',
#      'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1322208189669023750/pu/img/xR-sX_dlfysy_orJ.jpg',
#      'url': 'https://t.co/voxNnIYMpe',
#      'display_url': 'pic.twitter.com/voxNnIYMpe',
#      'expanded_url': 'https://twitter.com/realDonaldTrump/status/1322209177268154375/video/1',
#      'type': 'video',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#       'large': {'w': 1280, 'h': 720, 'resize': 'fit'}},
#      'source_status_id': 1322209177268154375,
#      'source_status_id_str': '1322209177268154375',
#      'source_user_id': 25073877,
#      'source_user_id_str': '25073877',
#      'video_info': {'aspect_ratio': [16, 9],
#       'duration_millis': 83413,
#       'variants': [{'bitrate': 2176000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/1322208189669023750/pu/vid/1280x720/sMtOQFuBCb8s_DVW.mp4?tag=10'},
#        {'bitrate': 256000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/1322208189669023750/pu/vid/480x270/bP0ENtSE1OPjMaR2.mp4?tag=10'},
#        {'content_type': 'application/x-mpegURL',
#         'url': 'https://video.twimg.com/ext_tw_video/1322208189669023750/pu/pl/kaS6jxiu25pGZQRU.m3u8?tag=10'},
#        {'bitrate': 832000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/1322208189669023750/pu/vid/640x360/jInFGSMMihR4qYwW.mp4?tag=10'}]},
#      'additional_media_info': {'monetizable': False,
#       'source_user': {'id': 25073877,
#        'id_str': '25073877',
#        'name': 'Donald J. Trump',
#        'screen_name': 'realDonaldTrump',
#        'location': 'Washington, DC',
#        'description': '45th President of the United States of America🇺🇸',
#        'url': 'https://t.co/8f9VFxztEJ',
#        'entities': {'url': {'urls': [{'url': 'https://t.co/8f9VFxztEJ',
#            'expanded_url': 'http://Vote.DonaldJTrump.com',
#            'display_url': 'Vote.DonaldJTrump.com',
#            'indices': [0, 23]}]},
#         'description': {'urls': []}},
#        'protected': False,
#        'followers_count': 88010918,
#        'friends_count': 50,
#        'listed_count': 123365,
#        'created_at': 'Wed Mar 18 13:46:38 +0000 2009',
#        'favourites_count': 6,
#        'utc_offset': None,
#        'time_zone': None,
#        'geo_enabled': True,
#        'verified': True,
#        'statuses_count': 58127,
#        'lang': None,
#        'contributors_enabled': False,
#        'is_translator': False,
#        'is_translation_enabled': True,
#        'profile_background_color': '6D5C18',
#        'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#        'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#        'profile_background_tile': True,
#        'profile_image_url': 'http://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#        'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#        'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25073877/1604214583',
#        'profile_link_color': '1B95E0',
#        'profile_sidebar_border_color': 'BDDCAD',
#        'profile_sidebar_fill_color': 'C5CEC0',
#        'profile_text_color': '333333',
#        'profile_use_background_image': True,
#        'has_extended_profile': False,
#        'default_profile': False,
#        'default_profile_image': False,
#        'following': False,
#        'follow_request_sent': False,
#        'notifications': False,
#        'translator_type': 'regular'}}}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 25073877,
#    'id_str': '25073877',
#    'name': 'Donald J. Trump',
#    'screen_name': 'realDonaldTrump',
#    'location': 'Washington, DC',
#    'description': '45th President of the United States of America🇺🇸',
#    'url': 'https://t.co/8f9VFxztEJ',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/8f9VFxztEJ',
#        'expanded_url': 'http://Vote.DonaldJTrump.com',
#        'display_url': 'Vote.DonaldJTrump.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 88010918,
#    'friends_count': 50,
#    'listed_count': 123365,
#    'created_at': 'Wed Mar 18 13:46:38 +0000 2009',
#    'favourites_count': 6,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 58127,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': '6D5C18',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25073877/1604214583',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': 'BDDCAD',
#    'profile_sidebar_fill_color': 'C5CEC0',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Fri Oct 30 16:10:07 +0000 2020',
#    'id': 1322209177268154375,
#    'id_str': '1322209177268154375',
#    'text': 'https://t.co/voxNnIYMpe',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [],
#     'media': [{'id': 1322208189669023750,
#       'id_str': '1322208189669023750',
#       'indices': [0, 23],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1322208189669023750/pu/img/xR-sX_dlfysy_orJ.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1322208189669023750/pu/img/xR-sX_dlfysy_orJ.jpg',
#       'url': 'https://t.co/voxNnIYMpe',
#       'display_url': 'pic.twitter.com/voxNnIYMpe',
#       'expanded_url': 'https://twitter.com/realDonaldTrump/status/1322209177268154375/video/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#        'large': {'w': 1280, 'h': 720, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1322208189669023750,
#       'id_str': '1322208189669023750',
#       'indices': [0, 23],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1322208189669023750/pu/img/xR-sX_dlfysy_orJ.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1322208189669023750/pu/img/xR-sX_dlfysy_orJ.jpg',
#       'url': 'https://t.co/voxNnIYMpe',
#       'display_url': 'pic.twitter.com/voxNnIYMpe',
#       'expanded_url': 'https://twitter.com/realDonaldTrump/status/1322209177268154375/video/1',
#       'type': 'video',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#        'large': {'w': 1280, 'h': 720, 'resize': 'fit'}},
#       'video_info': {'aspect_ratio': [16, 9],
#        'duration_millis': 83413,
#        'variants': [{'bitrate': 2176000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1322208189669023750/pu/vid/1280x720/sMtOQFuBCb8s_DVW.mp4?tag=10'},
#         {'bitrate': 256000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1322208189669023750/pu/vid/480x270/bP0ENtSE1OPjMaR2.mp4?tag=10'},
#         {'content_type': 'application/x-mpegURL',
#          'url': 'https://video.twimg.com/ext_tw_video/1322208189669023750/pu/pl/kaS6jxiu25pGZQRU.m3u8?tag=10'},
#         {'bitrate': 832000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1322208189669023750/pu/vid/640x360/jInFGSMMihR4qYwW.mp4?tag=10'}]},
#       'additional_media_info': {'monetizable': False}}]},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 25073877,
#     'id_str': '25073877',
#     'name': 'Donald J. Trump',
#     'screen_name': 'realDonaldTrump',
#     'location': 'Washington, DC',
#     'description': '45th President of the United States of America🇺🇸',
#     'url': 'https://t.co/8f9VFxztEJ',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/8f9VFxztEJ',
#         'expanded_url': 'http://Vote.DonaldJTrump.com',
#         'display_url': 'Vote.DonaldJTrump.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 88010918,
#     'friends_count': 50,
#     'listed_count': 123365,
#     'created_at': 'Wed Mar 18 13:46:38 +0000 2009',
#     'favourites_count': 6,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': True,
#     'statuses_count': 58127,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': True,
#     'profile_background_color': '6D5C18',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25073877/1604214583',
#     'profile_link_color': '1B95E0',
#     'profile_sidebar_border_color': 'BDDCAD',
#     'profile_sidebar_fill_color': 'C5CEC0',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'regular'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 12415,
#    'favorite_count': 66324,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'und'},
#   'is_quote_status': False,
#   'retweet_count': 12415,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'und'}]

# %%
# we'll take our results and turn them into a dataframe
results = pd.DataFrame({
    'name': [result['user']['name'] for result in tweet_results],
    'screen_name': [result['user']['screen_name'] for result in tweet_results],
    'text': [result['text'] for result in tweet_results],
    'retweets': [result['retweet_count'] for result in tweet_results],
    'favorites': [result['favorite_count'] for result in tweet_results],
    'id': [result['id_str'] for result in tweet_results]
})

print(f"API call brought in {results.shape[0]} new tweets")
results.head()
# Out:
# API call brought in 21 new tweets
#               name      screen_name  \
# 0  Donald J. Trump  realDonaldTrump
# 1  Donald J. Trump  realDonaldTrump
# 2  Donald J. Trump  realDonaldTrump
# 3  Donald J. Trump  realDonaldTrump
# 4  Donald J. Trump  realDonaldTrump
#
#                                                 text  retweets  favorites  \
# 0  RT @GOPLeader: The Republican coalition is big...      3250          0
# 1  Our lawyers have asked for “meaningful access”...     24048     114338
# 2  .....there was a large number of secretly dump...         0          0
# 3  We have claimed, for Electoral Vote purposes, ...     49889     207707
# 4  We are winning Pennsylvania big, but the PA Se...     52149     292330
#
#                     id
# 0  1324131291135168512
# 1  1324130551234727936
# 2  1324108206801563650
# 3  1324108200141082624
# 4  1324061986779504642

# %% [markdown]
# ### Step 3:  Checking For New Values

# %%
# this does a check for new values
# left merge means 'tweets' is the dominant table
# indicator lets you know if the value was present in one of the tables or both
results.merge(tweets, on='id', how='left', indicator=True)
# Out:
#              name_x    screen_name_x  \
# 0   Donald J. Trump  realDonaldTrump
# 1   Donald J. Trump  realDonaldTrump
# 2   Donald J. Trump  realDonaldTrump
# 3   Donald J. Trump  realDonaldTrump
# 4   Donald J. Trump  realDonaldTrump
# 5   Donald J. Trump  realDonaldTrump
# 6   Donald J. Trump  realDonaldTrump
# 7   Donald J. Trump  realDonaldTrump
# 8   Donald J. Trump  realDonaldTrump
# 9   Donald J. Trump  realDonaldTrump
# 10  Donald J. Trump  realDonaldTrump
# 11  Donald J. Trump  realDonaldTrump
# 12  Donald J. Trump  realDonaldTrump
# 13  Donald J. Trump  realDonaldTrump
# 14  Donald J. Trump  realDonaldTrump
# 15  Donald J. Trump  realDonaldTrump
# 16  Donald J. Trump  realDonaldTrump
# 17  Donald J. Trump  realDonaldTrump
# 18  Donald J. Trump  realDonaldTrump
# 19  Donald J. Trump  realDonaldTrump
# 20  Donald J. Trump  realDonaldTrump
# 21  Donald J. Trump  realDonaldTrump
# 22  Donald J. Trump  realDonaldTrump
# 23  Donald J. Trump  realDonaldTrump
# 24  Donald J. Trump  realDonaldTrump
# 25  Donald J. Trump  realDonaldTrump
# 26  Donald J. Trump  realDonaldTrump
# 27  Donald J. Trump  realDonaldTrump
# 28  Donald J. Trump  realDonaldTrump
# 29  Donald J. Trump  realDonaldTrump
# 30  Donald J. Trump  realDonaldTrump
# 31  Donald J. Trump  realDonaldTrump
# 32  Donald J. Trump  realDonaldTrump
#
#                                                text_x  retweets_x  \
# 0   RT @GOPLeader: The Republican coalition is big...        3250
# 1   Our lawyers have asked for “meaningful access”...       24048
# 2   .....there was a large number of secretly dump...           0
# 3   .....there was a large number of secretly dump...           0
# 4   We have claimed, for Electoral Vote purposes, ...       49889
# 5   We have claimed, for Electoral Vote purposes, ...       49889
# 6   We are winning Pennsylvania big, but the PA Se...       52149
# 7   We are winning Pennsylvania big, but the PA Se...       52149
# 8   Wow! It looks like Michigan has now found the ...       62856
# 9   Wow! It looks like Michigan has now found the ...       62856
# 10  They are working hard to make up 500,000 vote ...           0
# 11  They are working hard to make up 500,000 vote ...           0
# 12  They are finding Biden votes all over the plac...       87800
# 13  They are finding Biden votes all over the plac...       87800
# 14    WHAT IS THIS ALL ABOUT? https://t.co/6487pYLZnL       39988
# 15    WHAT IS THIS ALL ABOUT? https://t.co/6487pYLZnL       39988
# 16  How come every time they count Mail-In ballot ...       78643
# 17  How come every time they count Mail-In ballot ...       78643
# 18  Last night I was leading, often solidly, in ma...           0
# 19  Last night I was leading, often solidly, in ma...           0
# 20  RT @TeamTrump: LIVE: President Donald J Trump ...       37401
# 21  RT @TeamTrump: LIVE: President Donald J Trump ...       37401
# 22  We are up BIG, but they are trying to STEAL th...           0
# 23  We are up BIG, but they are trying to STEAL th...           0
# 24   I will be making a statement tonight. A big WIN!      132258
# 25   I will be making a statement tonight. A big WIN!      132258
# 26  RT @GOP: There is still time to get out and ca...        9081
# 27  WE ARE LOOKING REALLY GOOD ALL OVER THE COUNTR...      108948
# 28  Get out &amp; VOTE! Under my Administration, o...       28374
# 29  RT @realDonaldTrump: https://t.co/gsFSghkmdM h...       21868
# 30  RT @realDonaldTrump: https://t.co/gsFSgh2KPc h...       16329
# 31  RT @realDonaldTrump: https://t.co/gsFSghkmdM h...       14936
# 32       RT @realDonaldTrump: https://t.co/voxNnIYMpe       12415
#
#     favorites_x                   id           name_y    screen_name_y  \
# 0             0  1324131291135168512              NaN              NaN
# 1        114338  1324130551234727936              NaN              NaN
# 2             0  1324108206801563650  Donald J. Trump  realDonaldTrump
# 3             0  1324108206801563650  Donald J. Trump  realDonaldTrump
# 4        207707  1324108200141082624  Donald J. Trump  realDonaldTrump
# 5        207707  1324108200141082624  Donald J. Trump  realDonaldTrump
# 6        292330  1324061986779504642  Donald J. Trump  realDonaldTrump
# 7        292330  1324061986779504642  Donald J. Trump  realDonaldTrump
# 8        316627  1324059767581671425  Donald J. Trump  realDonaldTrump
# 9        316627  1324059767581671425  Donald J. Trump  realDonaldTrump
# 10            0  1324033983882166272  Donald J. Trump  realDonaldTrump
# 11            0  1324033983882166272  Donald J. Trump  realDonaldTrump
# 12       495294  1324032541544927233  Donald J. Trump  realDonaldTrump
# 13       495294  1324032541544927233  Donald J. Trump  realDonaldTrump
# 14       144104  1324012341458075648  Donald J. Trump  realDonaldTrump
# 15       144104  1324012341458075648  Donald J. Trump  realDonaldTrump
# 16       466262  1324007806694023169  Donald J. Trump  realDonaldTrump
# 17       466262  1324007806694023169  Donald J. Trump  realDonaldTrump
# 18            0  1324004491612618752  Donald J. Trump  realDonaldTrump
# 19            0  1324004491612618752  Donald J. Trump  realDonaldTrump
# 20            0  1323889136571437056  Donald J. Trump  realDonaldTrump
# 21            0  1323889136571437056  Donald J. Trump  realDonaldTrump
# 22            0  1323864823680126977  Donald J. Trump  realDonaldTrump
# 23            0  1323864823680126977  Donald J. Trump  realDonaldTrump
# 24       890842  1323864021167198209  Donald J. Trump  realDonaldTrump
# 25       890842  1323864021167198209  Donald J. Trump  realDonaldTrump
# 26            0  1323766095040385025  Donald J. Trump  realDonaldTrump
# 27       939519  1323765884268224514  Donald J. Trump  realDonaldTrump
# 28       179644  1323725991148167171  Donald J. Trump  realDonaldTrump
# 29            0  1323714393184653323  Donald J. Trump  realDonaldTrump
# 30            0  1323714331922583556  Donald J. Trump  realDonaldTrump
# 31            0  1323714155967373312  Donald J. Trump  realDonaldTrump
# 32            0  1323714095225384962  Donald J. Trump  realDonaldTrump
#
#                                                text_y  retweets_y  \
# 0                                                 NaN         NaN
# 1                                                 NaN         NaN
# 2   .....there was a large number of secretly dump...         0.0
# 3   .....there was a large number of secretly dump...         0.0
# 4   We have claimed, for Electoral Vote purposes, ...     46023.0
# 5   We have claimed, for Electoral Vote purposes, ...     46019.0
# 6   We are winning Pennsylvania big, but the PA Se...     51333.0
# 7   We are winning Pennsylvania big, but the PA Se...     51336.0
# 8   Wow! It looks like Michigan has now found the ...     61614.0
# 9   Wow! It looks like Michigan has now found the ...     61619.0
# 10  They are working hard to make up 500,000 vote ...         0.0
# 11  They are working hard to make up 500,000 vote ...         0.0
# 12  They are finding Biden votes all over the plac...     86607.0
# 13  They are finding Biden votes all over the plac...     86610.0
# 14    WHAT IS THIS ALL ABOUT? https://t.co/6487pYLZnL     39775.0
# 15    WHAT IS THIS ALL ABOUT? https://t.co/6487pYLZnL     39776.0
# 16  How come every time they count Mail-In ballot ...     78019.0
# 17  How come every time they count Mail-In ballot ...     78019.0
# 18  Last night I was leading, often solidly, in ma...         0.0
# 19  Last night I was leading, often solidly, in ma...         0.0
# 20  RT @TeamTrump: LIVE: President Donald J Trump ...     37312.0
# 21  RT @TeamTrump: LIVE: President Donald J Trump ...     37312.0
# 22  We are up BIG, but they are trying to STEAL th...         0.0
# 23  We are up BIG, but they are trying to STEAL th...         0.0
# 24   I will be making a statement tonight. A big WIN!    132144.0
# 25   I will be making a statement tonight. A big WIN!    132144.0
# 26  RT @GOP: There is still time to get out and ca...      5178.0
# 27  WE ARE LOOKING REALLY GOOD ALL OVER THE COUNTR...     48867.0
# 28  Get out &amp; VOTE! Under my Administration, o...      9516.0
# 29  RT @realDonaldTrump: https://t.co/gsFSghkmdM h...     14850.0
# 30  RT @realDonaldTrump: https://t.co/gsFSgh2KPc h...     11699.0
# 31  RT @realDonaldTrump: https://t.co/gsFSghkmdM h...     11580.0
# 32       RT @realDonaldTrump: https://t.co/voxNnIYMpe      8901.0
#
#     favorites_y     _merge
# 0           NaN  left_only
# 1           NaN  left_only
# 2           0.0       both
# 3           0.0       both
# 4      187590.0       both
# 5      187548.0       both
# 6      286551.0       both
# 7      286565.0       both
# 8      309044.0       both
# 9      309059.0       both
# 10          0.0       both
# 11          0.0       both
# 12     486834.0       both
# 13     486852.0       both
# 14     142850.0       both
# 15     142850.0       both
# 16     461075.0       both
# 17     461083.0       both
# 18          0.0       both
# 19          0.0       both
# 20          0.0       both
# 21          0.0       both
# 22          0.0       both
# 23          0.0       both
# 24     889817.0       both
# 25     889820.0       both
# 26          0.0       both
# 27     301369.0       both
# 28      46685.0       both
# 29          0.0       both
# 30          0.0       both
# 31          0.0       both
# 32          0.0       both

# %%
# we'll save the variable
merged_df = results.merge(tweets, on='id', how='left', indicator=True)

# %%
# select the values that are left_only in the _merge column -- these are new values
print(f"Found {merged_df[merged_df._merge == 'left_only'].shape[0]} new tweets not currently in the database")
merged_df[merged_df._merge == 'left_only']
# Out:
# Found 2 new tweets not currently in the database
#             name_x    screen_name_x  \
# 0  Donald J. Trump  realDonaldTrump
# 1  Donald J. Trump  realDonaldTrump
#
#                                               text_x  retweets_x  favorites_x  \
# 0  RT @GOPLeader: The Republican coalition is big...        3250            0
# 1  Our lawyers have asked for “meaningful access”...       24048       114338
#
#                     id name_y screen_name_y text_y  retweets_y  favorites_y  \
# 0  1324131291135168512    NaN           NaN    NaN         NaN          NaN
# 1  1324130551234727936    NaN           NaN    NaN         NaN          NaN
#
#       _merge
# 0  left_only
# 1  left_only

# %%
# get the index positions where this value is True
merged_df[merged_df._merge == 'left_only'].index
# Out:
# Int64Index([0, 1], dtype='int64')

# %%
results.index
# Out:
# RangeIndex(start=0, stop=21, step=1)

# %%
# use these values to look up tweets in the original results df
idx = merged_df[merged_df._merge == 'left_only'].index
# and these are our new tweets
results.iloc[idx]
# Out:
#               name      screen_name  \
# 0  Donald J. Trump  realDonaldTrump
# 1  Donald J. Trump  realDonaldTrump
#
#                                                 text  retweets  favorites  \
# 0  RT @GOPLeader: The Republican coalition is big...      3250          0
# 1  Our lawyers have asked for “meaningful access”...     24048     114338
#
#                     id
# 0  1324131291135168512
# 1  1324130551234727936

# %%
# and now we'll connect to the database and add in the values
with engine.connect() as connection:
    # declare data types for the db -- not necessary but a useful step if you are doing this the first time
    dtypes = {
        'name': types.String(length=65535),
        'screen_name': types.String(length=65535),
        'text': types.String(length=65535),
        'retweets': types.Integer(),
        'favorites': types.Integer(),
        'id': types.String(length=65535)
    }
    print("Adding values to database")
    try:
        results.iloc[idx].to_sql('tweets', con=connection, index=False, if_exists='append', dtype=dtypes)
        print("Successful")
    except Exception as e:
        print("Could not add results to the database.", e)
# Out:
# Adding values to database
# Successful
